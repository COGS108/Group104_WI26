# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [X] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This project examines changes in music sentiment over the past few decades alongside trends in alcohol and drug use disorders. Initially, our team intended to analyze how shifts in lyrical sentiment and repetitiveness might relate to broader mental health trends. However, due to the lack of accessible datasets covering recent years for mental health indicators, we redirected our focus to alcohol and drug use disorders, which are frequently referenced in modern music. Our objective was to determine whether mentions of alcohol and drugs in song lyrics correlate with real-world trends in substance use disorders.
#
# To conduct this analysis, we used a dataset containing top-ranking songs and their lyrics from the 1940s onward and paired it with a dataset of hospital admissions related to alcohol and drug use disorders beginning in the 1990s. The datasets were cleaned by removing null values, generating lyric sentiment scores using the VADER sentiment analysis tool, and constructing a dictionary of terms associated with alcohol and drugs. While this dictionary mentioned many commonly used references, some mentions may have been missed due to slang or contextual language. Our findings revealed several interesting findings. The number of unique words in lyrics increased over time, but when normalized by song length, diversity in unique words declined. Drug and alcohol mentions in song lyrics also increased over time, while substance use disorder rates rose significantly beginning in the mid-2000s. Correlation analysis showed moderate positive relationships between substance mentions in lyrics and real-world substance use trends, as well as strong correlations between alcohol and drug use disorders. Additionally, higher frequencies of substance-related language were associated with lower lyrical sentiment scores, indicating more negative emotional tone.
#
# Overall, the results suggest that references to drugs and alcohol in popular music may partially reflect broader societal trends in substance use while also being associated with more negative lyrical sentiment.

# %% [markdown]
# ## Authors
#
# Team List and Credits:
# - Zaria Brand Flu: Background research, Writing - original draft
# - Brooke Kennedy: Conceptualization, Project administration
# - Chris Mo: Data Curation, Experimental investigation,
# - Nhu Duong: Analysis, Methodology, Software, Writing - review & editing
# - Quynh Le: Visualization, Writing, Analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# **Primary Research Question**
# Has the sentiment and linguistic complexity in the mainstream U.S. Billboard Hot 100 song lyrics changed over time, and how are these changes associated with trends in alcohol and drug use disorders in the United States?
#
# **Secondary Question**
# Do major societal disruptions, such as the COVID-19 pandemic, correspond with noticeable shifts in lyrical sentiment, vocabulary complexity, or substance-related references in popular music?
#
#
# **Independent Variables**
# Year (time)
# Alcohol use disorder prevalence
# Drug use disorder prevalence
#
#
# **Dependent Variables**
# Lyrical sentiment score
# Alcohol word mentions in lyrics
# Drug word mentions in lyrics
# Lexical diversity (unique words and normalized unique words)
#
#
# **Control Variables**
# Billboard rank
# Word count / song length
# Consistent yearly sampling from the Billboard dataset

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Over the past decade, researchers have begun to examine how references to substances in popular music relate to real-world patterns of substance use. Studies of mainstream songs show that mentions of alcohol and drugs tend to increase and decrease alongside national substance use trends, suggesting that music reflects what is happening in society (1). At the same time, research on individual listeners finds that people who listen to more songs with substance-related lyrics are also more likely to report higher substance use themselves (2).
#
# Together, these findings suggest that music is not just reflecting behavior, but may also play a role in shaping it. Substance-related themes appear across many different types of music, meaning exposure is widespread and not limited to one genre (2). Researchers believe that repeated exposure to these messages can make substance use seem more normal or acceptable over time (3).
#
# In addition, music and pop culture often present substance use in a way that can feel normalized or even appealing, especially to younger audiences. This kind of portrayal can influence how people think about the risks and acceptability of using substances (3). When combined with the idea that music reflects real-world trends (1), this suggests that music not only mirrors behavior but can also influence and shape it over time.
#
# By focusing specifically on substance-related references in popular music and how they align with real-world patterns of substance use, this project builds on past research, aiming to better understand the relationship between cultural musical expression and public health. Examining how often drugs and alcohol appear in widely consumed songs alongside trends in substance use disorders can provide insight into how cultural exposure may relate to real-life behaviors and public health outcomes.
#
#
#
# 1. https://www.healio.com/news/psychiatry/20250523/hit-song-lyrics-reflect-national-trends-in-substance-use
# 2. https://www.tandfonline.com/doi/full/10.1080/23311908.2016.1220446
# 3. https://westlarecovery.com/the-influence-of-music-and-pop-culture-on-todays-drug-trends/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We, as a group, hypothesize that the sentiment of lyrics in mainstream U.S. Billboard songs have gradually become more negative and less semantically diverse over time. Additionally, we expect drugs and alcohol references in song lyrics to increase and to be associated with the increases in substance usage/disorders within the United States. Finally, we hypothesize that major societal crises, such as the COVID-19 pandemic (2020-2021) and 9/11 attack (2001), would result in an increase in substance-related lyrics and correspond with a relative increase in negative sentiment or an increase in emotionally comforting lyrics compared to the years preceding the pandemic.
#
# According to our background research, there is a rise in negative emotional language and reduced lyrical complexity in popular music over history. However, many studies also show that during periods of societal stress and pressure, listeners tend to seek music that provides emotional relief or nostalgia to recall memories. Therefore, we expect the COVID-19 pandemic to produce a measurable deviation from the long-term trend of increasing negativity in the lyrics.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Lyrics for Billboards Top 100 Songs 1946 - 2022
#   - Link to the dataset: https://www.kaggle.com/datasets/rhaamrozenberg/billboards-top-100-song-1946-to-2022-lyrics
#   - Number of observations: 6,879
#   - Number of variables: 5
#   - Variables:
#     - `Song`: Title of song in the billboard hot 100
#     - `Artist names`: List of artists in the song
#     - `Hot100 Ranking Year`: Year in which the song made the year-end hot 100
#     -` Hot100 Rank`: Song's rank within the year-end hot 100 list
#     - `Lyrics`: Preprocessed lyrics represented as a list of words split by whitespace, each element case standardized
#
# - Dataset #2
#   - Dataset Name: Trends of Alcohol and Drug Abuse in the United States from 1990-2023
#   - Link to dataset: https://vizhub.healthdata.org/gbd-results/?params=gbd-api-2023-permalink/644b62506f2f98642f81704c3afc94bd
#   - Number of observations: 612
#   - Number of Variables: 12
#   - Variables:
#     - `Population Group`: Which portion of the population is measured. In this case, they all have the value "All Population"
#     - `Measure`: What the data is measuring. In this case, they all have the value "Prevalence"
#     - `Metric`: Which metrics the data is measuring in. In this case, they all either have the value "Number" or "Percent" depending on what we aim to use.
#     - `Impairment`: These are the symptoms of either drug or alcohol abuse that patients are treated for. For example, heart failure.
#     - `Cause`: Cause of impairment from above. Since we filtered on the website, the only values are "Alcohol use disorder" and "Drug use disorder"
#     - `Location`: Location of the data. Since we filtered on the website, all values are "United States"
#     - `Age`: Age of the people represented in the data. Since we filtered on the website, all values are "All ages"
#     - `Sex`: Sex of the people represented in the data. Since we filtered on the website, all values are "Both sexes"
#     - `Year`: Year of the data collected.
#     - `Value`: Number or percentage of population treated for the impairment in question in a certain year.
#     - `Upper`: Upper 95% uncertainty level of the value provided
#     - `Lower`: Lower 95% uncertainty level of the value provided
#   - Shortcomings:
#     - Difficult to access, need to create an account to access and download the data
#     - Only refers to treated cases. Actual number may be higher, and there may be repeat patients for the same cause.
#
#
# We plan on merging the two data sets using Year as the primary key. This is appropriate, because both data sets represent time-based observations (things happening over time). The Billboard dataset records the year in which each song appeared on the Hot 100 chart, while the mental health dataset records the annual prevalence of drug and alcohol addiction in the United States
#
#
# In order to combine the datasets, we will first calculate metrics on the music by year, such as the lyrics’ sentiment and the diversity of lyrics used for the top songs each year. This creates yearly statistics for us to use, which we can align directly with our yearly mental health statistics. This means that after we have aggregated the data, each row in our dataset will represent one year, containing both music-related values and drug/alcohol use values.
#
#
# Overall, this will allow our group to examine our hypothesis of whether changes in lyrical sentiment or repetition correspond to broader societal trends occurring in the same year, such as shifts in mental health or drug/alcohol use.

# %% [markdown]
# ### A collection of lyrics from Billboard Top 100 songs ranging from 1946 to 2022
# This dataset contains five metrics: song name, lyrics, artist name, ranking year, and rank. Song name is the name of the song. Lyrics are the words of the song. The artist's name is the name of the artist who created the song being ranked. Ranking year is the year in which the song is being ranked. And rank is the song's placement in the top 100 during a given year. There are a few shortcomings with this dataset. The first shortcoming is that it only goes up to the year 2022, so we will either need to find a secondary dataset or lower the range we will be observing to match this dataset. Secondly, there are some null values in the lyrics column that we will have to filter out. To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis

# %%
import pandas as pd

lyric_df = pd.read_csv('data/02-processed/billboard_lyrics.csv')
lyric_df.head()
# Out:
#    Unnamed: 0                                  song            artists  year  \
# 0           0  Prisoner of Love - Remastered - 1992     ['perry como']  1946
# 1           1                       To Each His Own    ['eddy howard']  1946
# 2           2                             The Gypsy  ['the ink spots']  1946
# 3           3                     Five Minutes More  ['frank sinatra']  1946
# 4           4                     Rumors Are Flying  ['frankie carle']  1946
#
#    rank                                             lyrics  unique_words  \
# 0     1  ['someone', 'that', 'i', 'belong', 'to', 'does...          88.0
# 1     2  ['a', 'rose', 'must', 'remain', 'with', 'the',...          72.0
# 2     3  ['in', 'a', 'quaint', 'caravan', 'theres', 'a'...          66.0
# 3     4  ['dear', 'this', 'evening', 'seemed', 'to', 'g...          75.0
# 4     5  ['rumors', 'are', 'flying', 'that', 'youve', '...          71.0
#
# ...

# %%
import ast

lyric_df['artists'] = lyric_df['artists'].apply(ast.literal_eval)
lyric_df['lyrics'] = lyric_df['lyrics'].apply(ast.literal_eval)

# %% [markdown]
# ### Dataset #2 : Alcohol and Drug Abuse in the United States (1990-2023)
#
# The epidemiological component of this study utilizes data derived from the Global Health Data Exchange (GHDx), managed by the Institute for Health Metrics and Evaluation (IHME). This dataset represents a comprehensive longitudinal record of the burden of disease within the United States, specifically focusing on the evolution of substance use pathologies over a thirty-four-year period from 1990-2023. The dataset was subsetted to isolate primary health outcomes associated with Alcohol Use Disorders and Drug Use Disorders. The geographic focus is strictly limited to the United States, providing a national-level perspective. To ensure a generalized demographic baseline suitable for comparison, the data reflects Both Sexes and encompasses All Age groups. Likewise with the Billboard dataset, to see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis

# %%
drug_abuse = pd.read_csv('data/02-processed/drug_abuse_clean.csv')
drug_abuse.head()
# Out:
#    year                  cause        sum_val      mean_val
# 0  1990  Alcohol use disorders  159776.036177  39944.009044
# 1  1990     Drug use disorders    4959.055229    991.811046
# 2  1991  Alcohol use disorders  159067.077833  39766.769458
# 3  1991     Drug use disorders    5307.497527   1061.499505
# 4  1992  Alcohol use disorders  158130.671654  39532.667913

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# For our exploratory data analysis, we mainly focused on how different metrics changed over time, since both our datasets are temporal in nature (and why we decided to merge the two on the `year` column). We mainly aggregated the mean values for each measure because we wanted to see the effect of outliers in a given year, and in some cases also mapped the minimum and maximum values to give an idea of how each feature's value is spread throughout the dataset.

# %% [markdown]
# ### Exploring the Lyric Dataset
#
# We begin by examining the dataset that includes Billboard Year-end Hot 100 songs and their lyrics. From the data cleaning and wrangling step, we created a few additonal features that might be helpful to analyze the lyric data.

# %%
import matplotlib.pyplot as plt

bb_lyrics = lyric_df.groupby('year')[['unique_words', 'unique_no_stop', 'sentiment_score','unique_relative','alc_mentions','drug_mentions']].agg(['mean', 'min', 'max'])
bb_lyrics.columns = ['_'.join(col).strip() for col in bb_lyrics.columns.values]
bb_lyrics = bb_lyrics.reset_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(bb_lyrics['year'], bb_lyrics['unique_words_mean'], 
         label='Avg Unique Words', color='blue', linewidth=2)
plt.fill_between(bb_lyrics['year'], 
                 bb_lyrics['unique_words_min'], 
                 bb_lyrics['unique_words_max'], 
                 color='blue', alpha=0.15, label='Words Range (Min-Max)')
plt.plot(bb_lyrics['year'], bb_lyrics['unique_no_stop_mean'], 
         label='Avg No Stop Words', color='green', linewidth=2)
plt.fill_between(bb_lyrics['year'], 
                 bb_lyrics['unique_no_stop_min'], 
                 bb_lyrics['unique_no_stop_max'], 
                 color='green', alpha=0.15)

plt.title('Vocabulary Complexity Over Time')
plt.xlabel('Year')
plt.ylabel('Word Count')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
bb_lyrics.plot(x='year', y=['unique_words_mean', 'unique_no_stop_mean'], marker='o', figsize=(10, 5))
plt.title('Mean Unique Words in Lyrics Over Time')
plt.xlabel('Year')
plt.ylabel('Unique Words in a Song\'s Lyrics')
plt.show()

# %% [markdown]
# For the 'Vocabulary Complexity Over Time' graph, the blue and green lines indicate the average number of unique words per song and the average number of unique words excluding common stop words such as “the”, “and”, “you”, and “to” respectively.
# Before the 1960s, lyrics were written simply and used fewer unique words. However, starting from the 1960s, the complexity of lyrical vocabulary increased gradually through the early 2000s, indicating that a diverse range of distinct and meaningful words were used in lyrics. The plot had its highest peak in the 2005s and then slightly declined but remained at a higher rate compared to earlier decades. Overall, the two lines move closely over time, showing that lyrics in modern songs tend to use more varied and meaningful language rather than simply the repetition of common words in the mid 20th century.
#
#
# The graph after shows how the variety of words used in Billboard song lyrics has changed over time. The blue and orange lines show the average number of different words and average number of different meaningful words used in songs each year respectively. Both lines share a similar pattern which increases gradually from the 1960s and rises incredibly in the 1990s and 2000s where the lyrical diversity reaches its highest peak. Although there is a slight decrease after the 2000s, the number of unique words remains higher than in earlier years which suggests that modern songs tend to use a more diverse vocabulary.

# %%
bb_lyrics.plot(x='year', y='unique_relative_mean', marker='o', figsize=(10, 5))
plt.title('Normalized Unique Words in Lyrics Over Time')
plt.xlabel('Year')
plt.ylabel('Mean Unique Words Normalized By Song Length')
plt.show()

# %% [markdown]
# The 'Vocabulary Complexity Over Time Normalized by Length' graph shows the variety of words in song lyrics relative to the total length of the song. In other words, it measures how many different words are used compared to how long the lyrics are. The blue line represents the average proportion of unique words per song each year while the shaded area shows the range of values across songs in that year. Overall, the line slowly decreases from the late 1940s through the 2000s, suggesting that songs gradually used slightly fewer unique words relative to their length, meaning lyrics may have become somewhat more repetitive over time. In recent years, the trend levels off and increases slightly, but it still remains lower than the earliest years in the dataset.
# While the earlier two graphs show that the total number of unique and meaningful words in song lyrics increased over time, this graph looks at vocabulary diversity relative to the length of the song. When song length is carefully considered, the proportion of unique words slightly decreases over time which shows that although modern songs may contain more unique words overall, they may also repeat words or phrases more frequently within the lyrics. This helps explain why vocabulary counts increased in the earlier plots while the relative diversity of words appears to decline slightly in this normalized measure.
#
#
#
#
# The following graph shows the proportion of unique words used in song lyrics relative to the total number of words in each song over time. In the late 1940s, songs had a higher proportion of unique words which means that lyrics used more varied vocabulary relative to their length. After the early 1950s, the proportion dropped and then gradually declined through the following decades, suggesting that songs began repeating words or phrases more often. The numbers remained fairly stable from the 1970s through the early 2010s, with small fluctuations. In recent years, the proportion of unique words has increased slightly again, but it is still generally lower than the earliest years in the dataset which shows that lyrics today may still be more repetitive compared to earlier decades.

# %%
bb_lyrics.plot(x='year', y='sentiment_score_mean', marker='o', figsize=(10, 5))
plt.title('Lyric Sentiment Over Time')
plt.xlabel('Year')
plt.ylabel('Mean VADER Sentiment Score')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(bb_lyrics['year'], bb_lyrics['alc_mentions_mean'], 
         label='Mean Alcohol Mentions', color='blue', linewidth=2)
plt.plot(bb_lyrics['year'], bb_lyrics['drug_mentions_mean'], 
         label='Mean Drug Mentions', color='orange', linewidth=2)


plt.title('Vocabulary Over Time')
plt.xlabel('Year')
plt.ylabel('Word Count (Min-max Normalized)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# #### Exploring our Alcohol and Drug Abuse Dataset, Merging With Lyrics Dataset
#
# We now visualize the alcohol and drug dataframe and see if there are any interesting patterns within it and if any relationships exist between the content of the Billboard Hot 100 songs and the prevalence of alcohol or drug abuse in the United States at a given time.

# %%
alc_pivot = drug_abuse.pivot(index='year', columns='cause', values='mean_val').reset_index()
merged = bb_lyrics.merge(alc_pivot, on='year')
merged.rename(columns={
    'Alcohol use disorders': 'alcohol',
    'Drug use disorders': 'drugs'
}, inplace=True)
merged.head()
# Out:
#    year  unique_words_mean  unique_words_min  unique_words_max  \
# 0  1990         114.955556              37.0             304.0
# 1  1991         109.967033              42.0             274.0
# 2  1992         115.655556              57.0             307.0
# 3  1993         129.813953              41.0             314.0
# 4  1994         121.811111              48.0             330.0
#
#    unique_no_stop_mean  unique_no_stop_min  unique_no_stop_max  \
# 0            80.188889                25.0               242.0
# 1            75.483516                29.0               209.0
# 2            79.611111                32.0               265.0
# 3            92.383721                24.0               256.0
# 4            85.811111                27.0               264.0
#
#    sentiment_score_mean  sentiment_score_min  sentiment_score_max  ...  \
# 0              0.621310              -0.9995               0.9998  ...
# ...

# %% [markdown]
# We connect the Billboard Hot 100 lyrics dataset with the drug problem dataset to examine if lyrical trends in popular music align with more general societal patterns in substance usage. Song lyrics and information for songs that were listed on the Billboard Hot 100 chart between 1946 and 2022 are included in the lyrics dataset, which was acquired from Kaggle. We concentrate on the subset of songs that coincide with the available years in the substance disorder dataset for the purposes of our research.
#
# A number of variables in the lyrics dataset capture the linguistic and thematic elements of each song. In addition to processed textual elements taken from the lyrics, these include the song title, artist, year, and chart position.
# These characteristics include the total number of words, the number of unique words, the sentiment score, the normalized lexical diversity, and the number of mentions of alcohol and drugs that were found using keyword matching. Before analysis, the lyrics were also simplified to standardize word forms.
#
# The variable 'year' is used to combine the two datasets so that lyrical characteristics and societal changes can be compared. This guarantees that every song in the lyrics collection is linked to the matching annual statistics for drug and alcohol use problems in the US. Each row of the combined dataset produced by the merge process reflects a song and the drug use statistics for the year the song debuted on the Billboard chart.
# More than 6,000 songs make up the entire collection, which also includes signs of societal substance usage and lyrical characteristics. This combined dataset enables us to investigate possible connections between broader societal trends in substance use and lyrical topics, such as references to drugs or alcohol and emotional feeling in lyrics. By combining these datasets, the research can investigate if changes in mainstream music's lyrical content are correlated with an increase in drug or alcohol use disorders.

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
merged['drug_and_alc'] = merged['alcohol'] + merged['drugs']
scale_cols = ['sentiment_score_mean','drug_and_alc', 'alcohol', 'drugs', 'alc_mentions_mean','drug_mentions_mean']
merged[scale_cols] = scaler.fit_transform(
    merged[scale_cols])
plt.figure(figsize=(10,6))

sns.lineplot(data=merged, x='year', y='sentiment_score_mean', label='Sentiment')
sns.lineplot(data=merged, x='year', y='drug_and_alc', label='Drug & Alcohol Use Disorders')
plt.title('Sentiment and Substance Abuse Rate Over Time')
plt.ylabel('Relative Intensity (Min-Max Normalized)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(merged['year'], merged['alc_mentions_mean'], 
         label='Mean Alcohol Mentions', color='blue', linewidth=2)
plt.plot(merged['year'], merged['drug_mentions_mean'], 
         label='Mean Drug Mentions', color='orange', linewidth=2)
plt.plot(merged['year'], merged['drug_and_alc'], 
         label='Substance Abuse Rates', color='green', linewidth=2)


plt.title('Substance Mentions Relative to Substance Abuse Rates Over Time')
plt.xlabel('Year')
plt.ylabel('Relative Intensity (Min-Max Normalized)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### ETC AD NASEUM
#
# Now let's examine important events in the past 35 years, and whether they impacted substance abuse and/or song sentiments:
#
# - 1993: Waco Texas Standoff
# - 1995: Oklahoma City Bombing
# - 2001: 9/11 Terrorist Attacks
# - 2005: Hurricane Katrina
# - 2008: Global Financial Crisis
# - 2012: Sandy Hook
# - 2015: Same-sex marriage legalized
# - 2017: Las Vegas Shooting
# - 2020: COVID-19 Pandemic
#
# https://en.wikipedia.org/wiki/Timeline_of_the_history_of_the_United_States_(1990%E2%80%932009)
#
# https://en.wikipedia.org/wiki/Timeline_of_the_history_of_the_United_States_(2010%E2%80%93present)

# %%
import matplotlib.pyplot as plt

# 1. Create the base plot
plt.figure(figsize=(12, 6))
plt.plot(merged['year'], merged['sentiment_score_mean'], 
         label='Avg Sentiment', color='blue', linewidth=2)
plt.plot(merged['year'], merged['alcohol'], 
         label='Alcohol Abuse', color='green', linewidth=2)
plt.plot(merged['year'], merged['drugs'], 
         label='Drug Abuse', color='orange', linewidth=2)

plt.title('Vocabulary Complexity Over Time')
plt.xlabel('Year')
plt.ylabel('Word Count')
plt.legend()
plt.grid(True, alpha=0.3)

# 2. Define the events
events = {
    1993: "Waco",
    1995: "OKC Bombing",
    2001: "9/11",
    2005: "Hurricane Katrina",
    2008: "Financial Crisis",
    2012: "Sandy Hook",
    2015: "Marriage Equality",
    2017: "LV Shooting",
    2020: "COVID-19"
}

for year, label in events.items():
    plt.axvline(x=year, color='gray', linestyle='--', alpha=0.5)    
    plt.annotate(label, 
                 xy=(year, 0), 
                 xytext=(0, 10), 
                 textcoords='offset points', 
                 rotation=90, 
                 ha='center', 
                 fontsize=11, 
                 fontweight='bold',
                 color='darkred')

plt.title('Substance Mentions in Lyrics vs. Major US Events')
plt.xlabel('Year')
plt.ylabel('Relative Intensity (Min-Max Normalized)')
plt.legend(['Sentiment', 'Alcohol', 'Drugs'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Here, we can see the normalized values for overall drug and alcohol abuse disorders overlaid on the average lyric sentiment over time. As mentioned earlier, we initially aimed to see how transformative events like the 9/11 terrorist attacks and COVID-19 pandemic affect song sentiment and substance abuse. We plotted a few notable events and tragedies in the United States over the past 35 years, and visually found a few notable years.
#
# Starting with 2001, we see a noticable dip in average sentiment score, and a rise in alcohol and drug abuse--these results are consistent with our hypothesis, as a terrorist attack of this scale and cultural relevance likely sent shockwaves throughout the United States. Interestingly, the 2008 financial crises and COVID-19 pandemic had neutral or even positive effects on the lyric sentiment and lower alcohol abuse rates, which is contrary to our hypothesis. One possible explanation is that events like these inspire people to stay positive and optimistic about the future, and the lower alcohol abuse rates around 2020 could be explained by social gatherings like bars and clubs shuttering due to lockdown restrictions.

# %% [markdown]
# While exploratory analysis is useful, we attempt to validate our results statistically using OLS regression to see if alcohol mentions in lyrics (among other features) are a strong predictor for alcohol abuse rates.

# %%
import statsmodels.api as sm
import pandas as pd

X = merged[['alc_mentions_mean', 'sentiment_score_mean', 'year', 'unique_words_mean']]
X = sm.add_constant(X) 

y = merged['alcohol']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                alcohol   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     26.71
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):           3.35e-09
# Time:                        23:22:06   Log-Likelihood:                 12.412
# No. Observations:                  33   AIC:                            -14.82
# Df Residuals:                      28   BIC:                            -7.341
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -64.3962     11.758     -5.477      0.000     -88.481     -40.312
# ...

# %% [markdown]
# Based on the OLS regression, we can conclude that alcohol mentions in lyrics are not a direct, significant driver of alcohol abuse trends when controlling for time and song complexity. Instead, alcohol abuse appears to be driven by a long-term upward trend over the years, while the "simplification" of lyrics (lower unique word counts) tracks more closely with rising abuse than the specific mention of alcohol itself.
#
# We then repeat the process to examine drug mentions

# %%
X = merged[['drug_mentions_mean', 'sentiment_score_mean', 'year', 'unique_words_mean']]
X = sm.add_constant(X) 

y = merged['drugs']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  drugs   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     123.7
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):           2.28e-17
# Time:                        23:26:50   Log-Likelihood:                 39.924
# No. Observations:                  33   AIC:                            -69.85
# Df Residuals:                      28   BIC:                            -62.36
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -61.0916      4.276    -14.288      0.000     -69.850     -52.333
# ...

# %% [markdown]
# The OLS regression model for drug abuse rates demonstrates an exceptionally high goodness of fit, with an $R^2$ value of 0.946, indicating that approximately 95% of the variance in drug abuse prevalence is explained by the model's predictors. However, despite this high overall accuracy, the primary research hypothesis is not supported: `drug_mentions_mean` is statistically insignificant (p=0.995), meaning that the frequency of drug references in lyrics does not reliably predict drug abuse rates when other factors are considered. Similar to the alcohol model, the results are almost entirely dominated by the year variable (p<0.001), which shows a significant positive coefficient (0.0308), highlighting a consistent upward trend in drug abuse over time that exists independently of lyrical content. Additionally, the low Durbin-Watson statistic (0.214) suggests strong positive autocorrelation, reinforcing that while the rise in drug abuse is highly linear over time, it cannot be statistically attributed to the shift in musical sentiment or substance-related vocabulary within this multivariate framework.

# %% [markdown]
# We now try to implement an interrupted time series to see if a given event "interrupts" the metric's existing trajectory. Specifically, we will examine the effects of the notable events displayed above and song lyric sentiment. We begin by defining a function that allows us to observe the significance:

# %%
import statsmodels.formula.api as smf

def examine_year(year, event):
    its_df = merged.copy()

    its_df['time'] = its_df['year'] - its_df['year'].min()
    its_df[f'post_{event}'] = (its_df['year'] >= year).astype(int)
    its_df[f'time_after_{event}'] = (its_df['year'] - year).clip(lower=0)

    model_its = smf.ols(f'sentiment_score_mean ~ time + post_{event} + time_after_{event}', data=its_df).fit()
    print(model_its.summary())
    return model_its

examine_year(2020, 'covid')
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     sentiment_score_mean   R-squared:                       0.548
# Model:                              OLS   Adj. R-squared:                  0.501
# Method:                   Least Squares   F-statistic:                     11.71
# Date:                  Mon, 16 Mar 2026   Prob (F-statistic):           3.37e-05
# Time:                          23:45:54   Log-Likelihood:                 14.875
# No. Observations:                    33   AIC:                            -21.75
# Df Residuals:                        29   BIC:                            -15.76
# Df Model:                             3
# Covariance Type:              nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.7773      0.059     13.269      0.000       0.658       0.897
# ...

# %% [markdown]
# As shown, the `post_covid` variable shows that sentiment decreases very slightly after 2020, but the p-value of 0.77 shows that the result is not significant.

# %%
examine_year(2008, 'recession')
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     sentiment_score_mean   R-squared:                       0.602
# Model:                              OLS   Adj. R-squared:                  0.561
# Method:                   Least Squares   F-statistic:                     14.64
# Date:                  Mon, 16 Mar 2026   Prob (F-statistic):           5.46e-06
# Time:                          23:45:57   Log-Likelihood:                 16.995
# No. Observations:                    33   AIC:                            -25.99
# Df Residuals:                        29   BIC:                            -20.00
# Df Model:                             3
# Covariance Type:              nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.8041      0.070     11.524      0.000       0.661       0.947
# ...

# %% [markdown]
# The Interrupted Time Series (ITS) analysis of the 2008 recession reveals a significant and somewhat counter-intuitive shift in musical sentiment. While the model confirms a strong long-term negative trend in sentiment (p=0.001), where scores decreased by approximately 0.025 units per year, there was a statistically significant positive "step change" immediately following the recession (coef=0.2454, p=0.030). This suggests that in the immediate wake of the economic crisis, mainstream song lyrics actually became more positive, potentially serving as a form of "escapism" or "comfort" for listeners. However, this shift did not fundamentally alter the trajectory of music; the slope change (p=0.486) was not significant, indicating that after the initial boost, sentiment simply returned to its gradual, decades-long decline. With an $R^2$ of 0.602, the model effectively demonstrates that while the 2008 recession caused a temporary positive spike in the "mood" of lyrics, it was not enough to reverse the broader cultural trend toward darker lyrical content.

# %% [markdown]
# ## Ethics

# %% [markdown]
# A1 Informed Consent (x): We used publicly available data such as Billboard chart rankings, Spotify popularity metrics, and published song lyrics. Since we did not collect data directly from individuals and no private people can be identified in our dataset, informed consent is not applicable to this project.
#
# A2 Collection Bias (relevant): Our dataset intentionally focuses on mainstream U.S. pop music by sampling the top Billboard-charting songs each year. While this aligns with our research question, chart rankings reflect commercial success and industry promotion rather than the full diversity of musical expression. As a result, our findings describe trends in mainstream popular music consumption and should not be generalized to all genres, independent artists, or global music cultures.
#
# A3 Limit PII Exposure (x): The dataset contains only publicly released song lyrics and chart information. It does not include personal information such as contact details or private user data. As a result, risks related to exposing personal information are minimal.
#
# A4 Downstream Bias Mitigation (relevant): Our project looks at lyrical sentiment during major societal crises and discusses how music may reflect cultural mood or coping. There is a risk that our findings could be misinterpreted as statements about individual mental health or generational traits. To reduce this risk, we present our results as trends in mainstream music rather than direct measures of psychological well-being. We also avoid making claims about specific demographic groups because our dataset does not include information such as race or gender.
#
#
#
# B1 Data Security (relevant): Even though our dataset is publicly available, we take steps to store it responsibly. The data are kept in secure university accounts and repositories. These practices help prevent unauthorized changes, accidental loss, or misuse of analyses related to sensitive societal events.
#
# B2 Right To Be Forgotten (x): Our dataset consists of publicly released lyrics and chart rankings and does not include personal data from private individuals. Because of this, the right to request removal of personal information does not apply to this project.
#
# B3 Data Retention Plan (relevant): While the dataset contains public information and contains minimal privacy risk, we still aim to manage it responsibly. We plan to keep only the cleaned dataset and analysis code needed for reproducibility and delete temporary or duplicate files after the project is complete. This helps minimize unnecessary data storage while maintaining transparency.
#
# C1 Missing Perspectives (relevant): We recognize that our analysis focuses on mainstream U.S. pop music, which may overlook independent, niche, or non-English songs. We have discussed our assumptions with peers and reviewed literature on cultural and societal trends to ensure our interpretations consider broader context and avoid overgeneralizing from our dataset.
#
# C2 Dataset Bias (relevant): Our dataset includes only top songs in the U.S., which reflects commercial popularity rather than the full diversity of music. We acknowledge that certain genres, independent artists, and non-English music are underrepresented, and we limit our conclusions to trends in mainstream pop.
#
# C3 Honest Representation (relevant): Our visualizations and summary statistics accurately reflect the underlying dataset. We avoid overstating trends and clearly indicate when changes are specific to mainstream pop music or linked to specific crises.
#
# C4 Privacy In Analysis (x): Our dataset contains only public song lyrics and chart metadata. No personally identifiable information is included, so privacy risks in the analysis are minimal.
#
# C5 Auditability (relevant): We document all steps of data cleaning, evaluating lyrical sentiments, and other analysis, and store the dataset and code in repositories so that our results can be reproduced and verified if needed. Additionally, we plan to carefully review how Billboard determines the Top 100 each week, including how “listens” are counted across different platforms (streaming, CDs, etc.), to identify any groups that may be underrepresented. While we haven’t yet decided whether to include information about artists’ backgrounds (race, gender, etc.), we recognize that incorporating this could expand the project scope significantly, and we will carefully consider the ethical implications before including such data.
#
#
# D1 Proxy Discrimination (relevant): Our analysis uses publicly available song lyrics and chart data, which do not include sensitive personal attributes. We have reviewed our variables (e.g., Billboard rank, weeks on chart, and lyrical sentiments) to ensure they do not serve as proxies for protected characteristics, and we avoid drawing conclusions about individual artists or demographic groups.
#
# D2 Fairness Across Groups (relevant): Since our project focuses on overall trends in mainstream U.S. pop music, we do not make predictions about individual artists or demographic groups. However, we are aware that certain genres, artist types, and underrepresented groups may not be fully captured in our dataset, and we frame all findings in terms of mainstream pop music trends.
#
# D3 Metric Selection (relevant): We use multiple metrics to evaluate lyrical trends, including sentiment scores (how positive/negative the lyrics are) and measures of lexical diversity (how varied the lyrical vocabulary is). This allows us to capture different aspects of the lyrics and avoid drawing conclusions based on a single metric.
#
# D4 Explainability (relevant): Our analysis methods, including sentiment evaluation and lexical diversity calculations, are transparent and straightforward. We document how each metric is calculated and present results in ways that are interpretable to stakeholders and readers without technical expertise.
#
# D5 Communicate Limitations (relevant): We clearly communicate the limitations of our analysis, including the focus on mainstream U.S. pop music, potential underrepresentation of certain artists or genres, and the fact that sentiment scores are an approximation of lyrical tone rather than a measure of actual listener emotions. These limitations are highlighted in our reports and visualizations.
#
#
#
# E1 Monitoring And Evaluation (x): Our project analyzes historical data and does not involve a live system or predictive model. Therefore, ongoing performance monitoring is not applicable. However, we document all analysis steps carefully so that the process can be reviewed or audited if needed.
#
# E2 Redress (x): Since our work does not interact with users or produce real-time outputs, there is no risk of harm to individuals that would require a redress plan. We acknowledge that misinterpretation of results is possible, and we mitigate this by clearly communicating the scope and limitations of our findings.
#
# E3 Roll back (x): We do not have a deployed model in production, so there is no need for a rollback mechanism. All analysis is conducted offline using static datasets, and results are fully documented and reproducible.
#
# E4 Unintended Use (relevant): While our project does not involve a live deployed model, there is a possibility that others could misinterpret our findings (for example, claiming that negative lyrics indicate individual mental health trends). To prevent misuse, we clearly communicate that our results reflect trends in mainstream U.S. pop music and emphasize the limitations of the dataset and analysis.

# %% [markdown]
# ## Discusison and Conclusion
# The analysis of Billboard song lyrics reveals several trends in vocabulary use and thematic content over time. First, the results show that the total number of unique words used in song lyrics increased steadily from the 1960s through the early 2000s, reaching the highest levels around the mid-2000s. This indicates that modern songs tend to incorporate a broader range of vocabulary compared to songs from earlier decades. The similar movement of both vocabulary lines suggests that this increase reflects the use of more meaningful words rather. However, when vocabulary diversity is normalized by song length, the pattern changes. The proportion of unique words relative to the total number of words in each song gradually declines from the late 1940s through the 2000s. This suggests that although songs now contain more unique words overall, lyrics may repeat words or phrases more frequently, resulting in slightly lower vocabulary diversity relative to their length. This helps explain why the total vocabulary counts increased while the normalized measure shows a modest decline. The analysis also shows clear changes in substance-related themes in music lyrics.
#
# Drug and alcohol references appear very rarely in earlier decades but begin to increase noticeably starting in the late 1990s and continuing through the 2000s and 2010s. Alcohol mentions increase more sharply and reach higher levels than drug mentions, indicating that alcohol references are more common in mainstream music lyrics. Finally, the correlation analysis reveals several relationships between lyrical content and broader societal patterns. Sentiment scores in lyrics are moderately to strongly negatively correlated with substance use disorder levels, including drug use disorders (-0.73) and alcohol use disorders (-0.64). This suggests that as substance use disorders increase in society, the emotional tone of song lyrics tends to become less positive. In addition, substance mentions in lyrics show positive correlations with real-world substance use trends, particularly for drug references (approximately 0.54), indicating that lyrical themes may partially reflect broader societal patterns of substance use.
#
# Previous studies have shown that mentions of substance in songs tend to increase and decrease in parallel with substance abuse in society. They have also shown that people who tend to listen to songs that mention substance usage are more likely to report their own use of substances like alcohol or drugs. Our data analysis shows a similar trend since the second dataset we use is based on hospital admissions. This compared to the mentions of alcohol and drugs in song lyrics dictionary we used shows a positive correlation between the mention of substances and the use of said substances.
#
# There are a few limits to our datasets. First, both of our datasets do not reach up to 2025, which would have been ideal considering it would have allowed us to have a more up-to-date data on song lyrical sentiments and alcohol and/or drug disorders. Second, these Drug and Alcohol disorder dataset is based on hospital admissions so it is potentially not a good representative dataset. Third, there is the risk that our lyrica analysis for words representing drugs or alcohol is not correct considering the use of slang words, words that have double meaning, and songs that portray these topics by using analogies or hidden contexts.
#
# Overall, the results suggest that popular music lyrics have become more linguistically complex over time, with modern songs using a greater number of unique and meaningful words compared to earlier decades. At the same time, the normalized vocabulary analysis indicates that lyrics may have become slightly more repetitive relative to song length. In addition to linguistic changes, the study also highlights a growing presence of substance-related themes in song lyrics, particularly alcohol references, beginning in the late 1990s. The correlation analysis further suggests that these lyrical trends may be connected to broader societal patterns, as substance mentions in lyrics show positive relationships with real-world substance use statistics while lyrical sentiment becomes less positive during periods of higher substance use disorders. Together, these findings indicate that popular music lyrics not only evolve stylistically but may also reflect broader cultural and social trends, including shifts in emotional tone and the increasing visibility of substance-related themes in mainstream music. However, there were a few contradictions in our results such as: vocabulary increased by diversity decreased, substances mentioned with negative sentiment, alcohol having a weak correlation with alcohol disorders while drugs have a moderate correlation with drug disorders.
