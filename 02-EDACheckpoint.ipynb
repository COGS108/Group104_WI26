# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Team List and Credits:
# - Zaria Brand Flu: Background research, Writing - original draft
# - Brooke Kennedy: Conceptualization, Project administration
# - Chris Mo: Data Curation, Experimental investigation,
# - Nhu Duong: Analysis, Methodology, Software, Writing - review & editing
# - Quynh Le: Visualization, Writing, Analysis

# %% [markdown]
# # Research Question

# %% [markdown]
# Has the general sentiment of mainstream U.S. pop music lyrics become more negative and repetitive due to changes in alcohol and drug abuse in the past 30 years?
#
# More specifically, how did the sentiment of mainstream Spotify and Billboard pop music lyrics change during major societal crises (e.g., the COVID-19 pandemic) compared to the years immediately preceding those crises?
#
# Independent variables: Time (year) and crisis period (pre-COVID vs during COVID).
# Dependent variables: Lyrical sentiment scores and measures of lexical diversity derived from song lyrics.
# Controls variable: include song popularity (Billboard rank, weeks on chart) and consistent sampling across years.
#
# **WE NEED TØ REDO THIS**

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Over the past five decades, popular music lyrics have undergone systematic shifts in emotional tone, linguistic structure in lyrics, and thematic focus. (1) Lyrical analyses of song lyrics indicate that popular music has become increasingly repetitive and simple, with an emphasis on individual experiences and self expression. These major changes along with an increase in the negative emotional language indicated by words associated with sadness, anger, loneliness, and stress (2). Researchers suggest that these trends in lyrics are a reflection of a broader picture of cultural and psychological shifts within society, such as rising awareness of mental health issues and increased societal stress (3).
#
# The quantitative studies using large lyrical datasets, for our project, the Billboard charting songs and long term collection of popular music demonstrated consistent increases in first person pronouns in songs and more emotional negativity words and phrases. These findings help us strengthen the idea and hypothesis that music lyrics serve as a cultural artifact that mirrors the people, their emotional states and the social priorities of the society as a whole.
#
# Moreover, prior research tells us that these long term trends are not uniform and they tend to shift during different periods of major disruption in society. For example, large-scale crises such the Covid 19 pandemic, the patterns in music  production, lyrical messages and listener preferences changed noticeably. Listeners often lean to music that can provide emotional comfort and relief from stress (4).
#
# We noticed that there are fewer studies that use consistent popularity-based datasets, like the U.S. Billboard Top 100, to directly compare crisis periods to immediately prior years, despite a wealth of evidence of long-term shifts in lyrical emotion. By investigating whether the 9/11 attack and the COVID-19 pandemic reflects a visible shift from the long-term trend of rising negativity in popular U.S. pop music lyrics between 2000 and 2025, this project expands on previous research and continues to look at these patterns to find correlations between societal stress and music.
#
# Reference Links
#
#
# 1. https://www.nature.com/articles/s41598-024-55742-x
# 2. https://www.nature.com/articles/s41598-025-28327-5?fromPaywallRec=false
# 3. https://phys.org/news/2025-12-popular-song-lyrics-negative-analysis.html
# 4. https://www.wuss.org/proceedings/2025/WUSS-2025-Paper-174.pdf
#
# **WE NEED TO REDO THIS TOO*

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We, as a group, hypothesize that the period from 2000 to 2025, mainstream U.S. pop music lyrics have become increasingly negative in sentiment and less semantically diverse overall. We further hypothesize that the 9/11 (2021) attack and COVID-19 pandemic (2020–2021) is the reason for this temporarily disrupted this long-term trend, resulting in a relative decrease in negative sentiment or an increase in emotionally comforting lyrical content compared to the years immediately preceding the pandemic.
#
# According to our background research, there is a rise in negative emotional language and reduced lyrical complexity in popular music over history. However, many studies also show that during periods of societal stress and pressure, listeners tend to seek music that provides emotional relief or nostalgia to recall memories. Therefore, we expect the COVID-19 pandemic to produce a measurable deviation from the long-term trend of increasing negativity in the lyrics.
#
# **WE ALSO NEED TO REDO THIS**

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Lyrics for Billboards Top 100 Songs 1946 - 2022
#   - Link to the dataset: https://www.kaggle.com/datasets/rhaamrozenberg/billboards-top-100-song-1946-to-2022-lyrics
#   - Number of observations: 6,879
#   - Number of variables: 5
#   - Variables:
#     - `Song`: Title of song in the billboard hot 100
#     - `Artist names`: List of artists in the song
#     - `Hot100 Ranking Year`: Year in which the song made the year-end hot 100
#     -` Hot100 Rank`: Song's rank within the year-end hot 100 list
#     - `Lyrics`: Preprocessed lyrics represented as a list of words split by whitespace, each element case standardized
#
# - Dataset #2
#   - Dataset Name: Trends of Alcohol and Drug Abuse in the United States from 1990-2023
#   - Link to dataset: https://vizhub.healthdata.org/gbd-results/?params=gbd-api-2023-permalink/644b62506f2f98642f81704c3afc94bd
#   - Number of observations: 612
#   - Number of Variables: 12
#   - Variables:
#     - `Population Group`: Which portion of the population is measured. In this case, they all have the value "All Population"
#     - `Measure`: What the data is measuring. In this case, they all have the value "Prevalence"
#     - `Metric`: Which metrics the data is measuring in. In this case, they all either have the value "Number" or "Percent" depending on what we aim to use.
#     - `Impairment`: These are the symptoms of either drug or alcohol abuse that patients are treated for. For example, heart failure.
#     - `Cause`: Cause of impairment from above. Since we filtered on the website, the only values are "Alcohol use disorder" and "Drug use disorder"
#     - `Location`: Location of the data. Since we filtered on the website, all values are "United States"
#     - `Age`: Age of the people represented in the data. Since we filtered on the website, all values are "All ages"
#     - `Sex`: Sex of the people represented in the data. Since we filtered on the website, all values are "Both sexes"
#     - `Year`: Year of the data collected.
#     - `Value`: Number or percentage of population treated for the impairment in question in a certain year.
#     - `Upper`: Upper 95% uncertainty level of the value provided
#     - `Lower`: Lower 95% uncertainty level of the value provided
#   - Shortcomings:
#     - Difficult to access, need to create an account to access and download the data
#     - Only refers to treated cases. Actual number may be higher, and there may be repeat patients for the same cause.
#
#
# We plan on merging the two data sets using Year as the primary key. This is appropriate, because both data sets represent time-based observations (things happening over time). The Billboard dataset records the year in which each song appeared on the Hot 100 chart, while the mental health dataset records the annual prevalence of drug and alcohol addiction in the United States
#
#
# In order to combine the datasets, we will first calculate metrics on the music by year, such as the lyrics’ sentiment and the diversity of lyrics used for the top songs each year. This creates yearly statistics for us to use, which we can align directly with our yearly mental health statistics. This means that after we have aggregated the data, each row in our dataset will represent one year, containing both music-related values and drug/alcohol use values.
#
#
# Overall, this will allow our group to examine our hypothesis of whether changes in lyrical sentiment or repetition correspond to broader societal trends occurring in the same year, such as shifts in mental health or drug/alcohol use.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 

datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1har3-M6UhsLSLkfvsXH_x2rdyxfH_w7w', 'filename':'lyric_dataset.csv'},
    # { 'url': 'https://drive.google.com/uc?export=download&id=1FY19P0ApbPEPFObWy9pRza1Op7FLph_m', 'filename':'mental_health_dataset.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1BawahIer9eGevvinkDyvZIDkqOuIzoaA', 'filename':'drug_abuse_dataset.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:03<00:03,  3.19s/it]
# Successfully downloaded: lyric_dataset.csv
# ...
# Overall Download Progress: 100%|██████████| 2/2 [00:04<00:00,  2.30s/it]
# Successfully downloaded: drug_abuse_dataset.csv

# %% [markdown]
# ### A collection of lyrics from Billboard Top 100 songs ranging from 1946 to 2022
#     This dataset contains five metrics: song name, lyrics, artist name, ranking year, and rank. Song name is the name of the song. Lyrics are the words of the song. The artist's name is the name of the artist who created the song being ranked. Ranking year is the year in which the song is being ranked. And rank is the song's placement in the top 100 during a given year. There are a few shortcomings with this dataset. The first shortcoming is that it only goes up to the year 2022, so we will either need to find a secondary dataset or lower the range we will be observing to match this dataset. Secondly, there are some null values in the lyrics column that we will have to filter out.

# %%
import pandas as pd
import ast
lyric_df = pd.read_csv('./data/00-raw/lyric_dataset.csv')
## Rename columns for simplicity
lyric_df.columns = ['song','artists','year','rank','lyrics']
lyric_df['artists'] = lyric_df['artists'].apply(ast.literal_eval)
lyric_df
# Out:
#                                                    song  \
# 0                  Prisoner of Love - Remastered - 1992
# 1                                       To Each His Own
# 2                                             The Gypsy
# 3                                     Five Minutes More
# 4                                     Rumors Are Flying
# ...                                                 ...
# 6874                 Flower Shops (feat. Morgan Wallen)
# 6875  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 6876                                             Unholy
# 6877                                    One Mississippi
# 6878                           Circles Around This Town
#
#                                                 artists  year  rank  \
# 0                                          [perry como]  1946     1
# 1                                         [eddy howard]  1946     2
# 2                                       [the ink spots]  1946     3
# ...

# %%
print(f'There are {lyric_df.shape[0]} rows in the dataframe, with {lyric_df.shape[1]} columns.')
print("Examining null values, if any exist in the dataset")
print(lyric_df.isna().any())
print("As shown, there are null values in the Lyric column")
null_lyrics = lyric_df[lyric_df['lyrics'].isna()]
display(null_lyrics)
# Out:
# There are 6879 rows in the dataframe, with 5 columns.
# Examining null values, if any exist in the dataset
# song       False
# artists    False
# year       False
# rank       False
# lyrics      True
# dtype: bool
# As shown, there are null values in the Lyric column
#                                                    song  \
# 5                              Oh! What It Seemed to Be
# 13                                      To Each His Own
# 14                                   Ole Buttermilk Sky
# 17                                  The Old Lamplighter
# 20    Jocelyn, Op. 100: Berceuse (Arr. For vocal, vi...
# ...                                                 ...
# 6706  Dakiti (Originally Performed by Bad Bunny & Jh...
# 6725                                      Wants & Needs
# 6798                                 Yo Me Porto Bonito
# 6811                           Jimmy Cooks - Lofi Cover
# 6867                            A Holly Jolly Christmas
#
# ...

# %% [markdown]
# There are about 847 songs in our dataset without lyrics, but we plan to drop those. Many have "orchestra" in the author names and some are Lofi covers, which by nature do not have lyrics as well and may be based on other artists. One mentions Bad Bunny as an artist, and we may not be able to do meaningful language analysis on different languages at the moment.
#
# Thus, we decided to drop the values to make the data easier to work with. Since null values are only present in the lyric column, we can use `pd.dropna(how='any')` to drop the correct rows.

# %%
lyrics_clean = lyric_df.dropna(how='any')
lyrics_clean['lyrics'] = lyrics_clean['lyrics'].apply(ast.literal_eval)
display(lyrics_clean)
print("visualizing the distribution of years and rank in the clean dataset")
import matplotlib.pyplot as plt

lyrics_clean['year'].hist()
plt.show()
lyrics_clean['rank'].hist()
# Out:
# /tmp/ipykernel_1534/554765252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lyrics_clean['lyrics'] = lyrics_clean['lyrics'].apply(ast.literal_eval)
#                                                    song  \
# 0                  Prisoner of Love - Remastered - 1992
# 1                                       To Each His Own
# 2                                             The Gypsy
# 3                                     Five Minutes More
# 4                                     Rumors Are Flying
# ...                                                 ...
# 6874                 Flower Shops (feat. Morgan Wallen)
# 6875  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 6876                                             Unholy
# ...

# %%
lyrics_clean.to_csv('data/02-processed/billboard_lyrics.csv', index=False)

# %% [markdown]
# As shown, the 1940s-1950s had many more null lyric values than the rest of the dataset, likely because the songs are harder to find definitive lyrics for almost 80 years later. Since our secondary dataset only has data from 1990-2017, we will not have to worry about this particular problem. The rank also doesn't seem to affect the missingness, so our clean data is ready for analysis.

# %%
## gather data from those available in the mental health dataset: 1990-2017

filtered_years = lyrics_clean[(lyrics_clean['year'] >= 1990)&(lyrics_clean['year'] <= 2023)]
print("Adding some features that might be useful for EDA in the next checkpoint")
filtered_years['num_artists'] = filtered_years['artists'].apply(len)
filtered_years['num_unique_words'] = filtered_years['lyrics'].apply(lambda x: len(set(x)))
filtered_years
# Out:
# Adding some features that might be useful for EDA in the next checkpoint
# /tmp/ipykernel_1534/1731117156.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_years['num_artists'] = filtered_years['artists'].apply(len)
# /tmp/ipykernel_1534/1731117156.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_years['num_unique_words'] = filtered_years['lyrics'].apply(lambda x: len(set(x)))
#                                                    song  \
# ...

# %% [markdown]
# ### Dataset #2 : Alcohol and Drug Abuse in the United States (1990-2023)
#
# `The epidemiological component of this study utilizes data derived from the Global Health Data Exchange (GHDx), managed by the Institute for Health Metrics and Evaluation (IHME). This dataset represents a comprehensive longitudinal record of the burden of disease within the United States, specifically focusing on the evolution of substance use pathologies over a thirty-four-year period from 1990-2023. The dataset was subsetted to isolate primary health outcomes associated with Alcohol Use Disorders and Drug Use Disorders. The geographic focus is strictly limited to the United States, providing a national-level perspective. To ensure a generalized demographic baseline suitable for comparison, the data reflects Both Sexes and encompasses All Age groups.`

# %%
drug_abuse = pd.read_csv('data/00-raw/drug_abuse_dataset.csv')
drug_abuse.drop(columns=['population_group','measure','location','sex','age'], inplace=True)
drug_abuse
# Out:
#                      cause                                    rei   metric  \
# 0       Drug use disorders                  Treated heart failure   Number
# 1       Drug use disorders                  Treated heart failure  Percent
# 2       Drug use disorders                  Treated heart failure   Number
# 3       Drug use disorders                  Treated heart failure  Percent
# 4    Alcohol use disorders  Developmental intellectual disability   Number
# ..                     ...                                    ...      ...
# 607  Alcohol use disorders       Moderate intellectual disability  Percent
# 608  Alcohol use disorders       Moderate intellectual disability   Number
# 609  Alcohol use disorders       Moderate intellectual disability  Percent
# 610     Drug use disorders                   Severe heart failure   Number
# 611     Drug use disorders                   Severe heart failure  Percent
#
#      year           val          upper         lower
# ...

# %%
drug_grouped = drug_abuse.groupby(['year', 'cause', 'metric']).agg(
    sum_val=('val', 'sum'),
    mean_val=('val', 'mean')
).reset_index()
drug_grouped
# Out:
#      year                  cause   metric        sum_val      mean_val
# 0    1990  Alcohol use disorders   Number  159776.036177  39944.009044
# 1    1990  Alcohol use disorders  Percent       0.020764      0.005191
# 2    1990     Drug use disorders   Number    4959.055229    991.811046
# 3    1990     Drug use disorders  Percent       0.000978      0.000196
# 4    1991  Alcohol use disorders   Number  159067.077833  39766.769458
# ..    ...                    ...      ...            ...           ...
# 131  2022     Drug use disorders  Percent       0.005242      0.001048
# 132  2023  Alcohol use disorders   Number  186339.717119  46584.929280
# 133  2023  Alcohol use disorders  Percent       0.020106      0.005027
# 134  2023     Drug use disorders   Number   67852.988185  13570.597637
# 135  2023     Drug use disorders  Percent       0.005315      0.001063
#
# [136 rows x 5 columns]

# %%
drug_grouped = drug_grouped[drug_grouped['metric'] == 'Number']
drug_grouped.drop(columns='metric',inplace=True)
drug_grouped
# Out:
# /tmp/ipykernel_1534/2414969358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_grouped.drop(columns='metric',inplace=True)
#      year                  cause        sum_val      mean_val
# 0    1990  Alcohol use disorders  159776.036177  39944.009044
# 2    1990     Drug use disorders    4959.055229    991.811046
# 4    1991  Alcohol use disorders  159067.077833  39766.769458
# 6    1991     Drug use disorders    5307.497527   1061.499505
# 8    1992  Alcohol use disorders  158130.671654  39532.667913
# ..    ...                    ...            ...           ...
# 126  2021     Drug use disorders   64827.803448  12965.560690
# 128  2022  Alcohol use disorders  185941.017372  46485.254343
# 130  2022     Drug use disorders   66532.330921  13306.466184
# ...

# %%
drug_grouped.isna().any()
# Out:
# year        False
# cause       False
# sum_val     False
# mean_val    False
# dtype: bool

# %%
drug_grouped.to_csv('data/02-processed/drug_abuse_clean.csv', index=False)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Exploring the Billboard Dataset
#
# To begin, we add features using NLTK to help us better understand the lyrics dataset.

# %%
import pandas as pd

bb_lyrics = pd.read_csv('data/02-processed/billboard_lyrics.csv')
display(bb_lyrics.head())
# Out:
#                                    song            artists  year  rank  \
# 0  Prisoner of Love - Remastered - 1992     ['perry como']  1946     1
# 1                       To Each His Own    ['eddy howard']  1946     2
# 2                             The Gypsy  ['the ink spots']  1946     3
# 3                     Five Minutes More  ['frank sinatra']  1946     4
# 4                     Rumors Are Flying  ['frankie carle']  1946     5
#
#                                               lyrics
# 0  ['someone', 'that', 'i', 'belong', 'to', 'does...
# 1  ['a', 'rose', 'must', 'remain', 'with', 'the',...
# 2  ['in', 'a', 'quaint', 'caravan', 'theres', 'a'...
# 3  ['dear', 'this', 'evening', 'seemed', 'to', 'g...
# 4  ['rumors', 'are', 'flying', 'that', 'youve', '...

# %%
# evaluating list strings as lists using ast
import ast

bb_lyrics['artists'] = bb_lyrics['artists'].apply(ast.literal_eval)
bb_lyrics['lyrics'] = bb_lyrics['lyrics'].apply(ast.literal_eval)

# %%
# adding word count features, as well as using the VADER sentiment analyzer to incorporate a sentiment score
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
sia = SentimentIntensityAnalyzer()

def process_lyrics(lyric_list):
    unique_all = len(set(lyric_list))
    word_count = len(lyric_list)
    filtered_tokens = [w for w in lyric_list if w not in stop_words]
    unique_no_stop = len(set(filtered_tokens))
    sentiment = sia.polarity_scores(' '.join(lyric_list))
    return pd.Series([unique_all, word_count, unique_no_stop, sentiment['compound']])

bb_lyrics[['unique_words', 'word_count', 'unique_no_stop', 'sentiment_score']] = bb_lyrics['lyrics'].apply(process_lyrics)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/zbrandflu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/zbrandflu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/zbrandflu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
bb_lyrics['unique_relative'] = bb_lyrics['unique_no_stop']/bb_lyrics['word_count']
bb_lyrics
# Out:
#                                                    song  \
# 0                  Prisoner of Love - Remastered - 1992
# 1                                       To Each His Own
# 2                                             The Gypsy
# 3                                     Five Minutes More
# 4                                     Rumors Are Flying
# ...                                                 ...
# 6027                 Flower Shops (feat. Morgan Wallen)
# 6028  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 6029                                             Unholy
# 6030                                    One Mississippi
# 6031                           Circles Around This Town
#
#                                                 artists  year  rank  \
# 0                                          [perry como]  1946     1
# 1                                         [eddy howard]  1946     2
# 2                                       [the ink spots]  1946     3
# ...

# %%
# A very rudimentary alcohol and drug instance checker, may need to update this in part 3 of the project

lexicons = {
    'alcohol': {'wine', 'beer', 'whiskey', 'vodka', 'tequila', 'drunk', 'bottle', 'hennessy', 'champagne', 'sip', 'liquid courage', 'booze', 'cold one', 'nightcap'},
    'drugs': {'weed', 'pills', 'cocaine', 'marijuana', 'blunt', 'smoke', 'narcotics', 'dose', 'zaza', 'pot' , 'dope', 'shrooms'}
}

def check_substances(lyric_list):
    counts = {category: 0 for category in lexicons.keys()}
    
    for word in lyric_list:
        word_lower = word.lower()
        for category, keywords in lexicons.items():
            if word_lower in keywords:
                counts[category] += 1
                
    return pd.Series(counts)

# %%
# We lemmatize our lyrics so that variations like "wines" and "smoking" refer back to the root word

from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

def clean_and_lemmatize(lyric_list):
    return [lemmatizer.lemmatize(w.lower()) for w in lyric_list]

bb_lyrics['lyrics_lemmatized'] = bb_lyrics['lyrics'].apply(clean_and_lemmatize)

bb_lyrics[['alc_mentions', 'drug_mentions']] = bb_lyrics['lyrics_lemmatized'].apply(check_substances)

bb_lyrics.plot(x='year',y='alc_mentions')
plt.show()
bb_lyrics.plot(x='year',y='drug_mentions')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/zbrandflu/nltk_data...
# <Axes: xlabel='year'>

# %%
#Number of drug words mentioned increases drastically at 2020 while mentions of alcohol decreased drastically

# %%
group_year = bb_lyrics.groupby('year')[['unique_words', 'unique_no_stop', 'sentiment_score','unique_relative','alc_mentions','drug_mentions']].agg(['mean', 'min', 'max'])
group_year.columns = ['_'.join(col).strip() for col in group_year.columns.values]
group_year = group_year.reset_index()
group_year
# Out:
#     year  unique_words_mean  unique_words_min  unique_words_max  \
# 0   1946          83.535714              33.0             182.0
# 1   1947          74.242424              33.0             243.0
# 2   1948          73.400000              29.0             163.0
# 3   1949          75.900000              38.0             173.0
# 4   1950          66.300000              18.0             156.0
# ..   ...                ...               ...               ...
# 72  2018         143.776596              25.0             399.0
# 73  2019         142.031250              29.0             311.0
# 74  2020         143.340206              21.0             387.0
# 75  2021         138.520833              48.0             295.0
# 76  2022         130.886598              51.0             298.0
#
#     unique_no_stop_mean  unique_no_stop_min  unique_no_stop_max  \
# 0             54.821429                19.0               141.0
# 1             48.636364                17.0               178.0
# ...

# %% [markdown]
# Visualizing our lyrics dataframe

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(group_year['year'], group_year['unique_words_mean'], 
         label='Avg Unique Words', color='blue', linewidth=2)
plt.fill_between(group_year['year'], 
                 group_year['unique_words_min'], 
                 group_year['unique_words_max'], 
                 color='blue', alpha=0.15, label='Words Range (Min-Max)')
plt.plot(group_year['year'], group_year['unique_no_stop_mean'], 
         label='Avg No Stop Words', color='green', linewidth=2)
plt.fill_between(group_year['year'], 
                 group_year['unique_no_stop_min'], 
                 group_year['unique_no_stop_max'], 
                 color='green', alpha=0.15)

plt.title('Vocabulary Complexity Over Time')
plt.xlabel('Year')
plt.ylabel('Word Count')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
group_year.plot(x='year', y=['unique_words_mean', 'unique_no_stop_mean'], marker='o', figsize=(10, 5))
# Out:
# <Axes: xlabel='year'>

# %%
plt.figure(figsize=(12, 6))
plt.plot(group_year['year'], group_year['unique_relative_mean'], 
         label='Avg Unique Words Relative to Song Length', color='blue', linewidth=2)
plt.fill_between(group_year['year'], 
                 group_year['unique_relative_min'], 
                 group_year['unique_relative_max'], 
                 color='blue', alpha=0.15, label='Words Range (Min-Max)')
plt.title('Vocabulary Complexity Over Time Normalized by Length')
plt.xlabel('Year')
plt.ylabel('Word Count Normalized by Song Length')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
group_year.plot(x='year', y='unique_relative_mean', marker='o', figsize=(10, 5))
# Out:
# <Axes: xlabel='year'>

# %%
#The average amount of unique word increased over time, however, when normalized to song lengths, the average actually decreases

# %%
group_year.plot(x='year', y='sentiment_score_mean', marker='o', figsize=(10, 5))
# Out:
# <Axes: xlabel='year'>

# %%
plt.scatter(x=bb_lyrics['sentiment_score'],y=bb_lyrics['unique_words'])

# %%
#Song with neutral sentiments tend to have less unique words compared to songs with either negative or positive sentiments

# %%
plt.figure(figsize=(12, 6))
plt.plot(group_year['year'], group_year['alc_mentions_mean'], 
         label='Avg Unique Words', color='blue', linewidth=2)
plt.fill_between(group_year['year'], 
                 group_year['alc_mentions_min'], 
                 group_year['alc_mentions_max'], 
                 color='blue', alpha=0.15, label='Words Range (Min-Max)')
plt.plot(group_year['year'], group_year['drug_mentions_mean'], 
         label='Avg No Stop Words', color='green', linewidth=2)
plt.fill_between(group_year['year'], 
                 group_year['drug_mentions_min'], 
                 group_year['drug_mentions_max'], 
                 color='green', alpha=0.15)

plt.title('Vocabulary Complexity Over Time')
plt.xlabel('Year')
plt.ylabel('Word Count')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
group_year.plot(x='year', y=['alc_mentions_mean', 'drug_mentions_mean'], marker='o', figsize=(10, 5))
# Out:
# <Axes: xlabel='year'>

# %%
#When we merge alcohol an drug nmentions, we see a trend in word mentioned spiking arouind the same time or go in opposite directions

# %% [markdown]
# #### Exploring our Alcohol and Drug Abuse Dataset, Merging With Lyrics Dataset
#
# We now visualize the alcohol and drug dataframe and see if there are any interesting patterns within it and if any relationships exist between the content of the Billboard Hot 100 songs and the prevalence of alcohol or drug abuse in the United States at a given time.

# %%
alc_drug = pd.read_csv('data/02-processed/drug_abuse_clean.csv')
display(alc_drug.head())
# Out:
#    year                  cause        sum_val      mean_val
# 0  1990  Alcohol use disorders  159776.036177  39944.009044
# 1  1990     Drug use disorders    4959.055229    991.811046
# 2  1991  Alcohol use disorders  159067.077833  39766.769458
# 3  1991     Drug use disorders    5307.497527   1061.499505
# 4  1992  Alcohol use disorders  158130.671654  39532.667913

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.lineplot(data=alc_drug, x='year', y='mean_val', hue='cause')

plt.title("Alcohol vs Drug Use Over Time")
plt.xlabel("Year")
plt.ylabel("Mean Value")
plt.show()

# %%
alc_var = alc_drug.groupby('year')['mean_val'].var().reset_index()
sns.lineplot(data=alc_var, x='year', y='mean_val')
# Out:
# <Axes: xlabel='year', ylabel='mean_val'>

# %%
merged = bb_lyrics.merge(alc_drug, on='year', how='inner')
merged
# Out:
#                                                    song  \
# 0                                               Hold On
# 1                                               Hold On
# 2     It Must Have Been Love - From the Film "Pretty...
# 3     It Must Have Been Love - From the Film "Pretty...
# 4                                  Nothing Compares 2 U
# ...                                                 ...
# 6057                                             Unholy
# 6058                                    One Mississippi
# 6059                                    One Mississippi
# 6060                           Circles Around This Town
# 6061                           Circles Around This Town
#
#                       artists  year  rank  \
# 0           [wilson phillips]  1990     1
# 1           [wilson phillips]  1990     1
# 2                   [roxette]  1990     2
# 3                   [roxette]  1990     2
# 4           [sinead o connor]  1990     3
# ...

# %%
alc_pivot = alc_drug.pivot(index='year', columns='cause', values='mean_val').reset_index()
merged2 = bb_lyrics.merge(alc_pivot, on='year')
merged2
# Out:
#                                                    song  \
# 0                                               Hold On
# 1     It Must Have Been Love - From the Film "Pretty...
# 2                                  Nothing Compares 2 U
# 3                                                Poison
# 4                                                 Vogue
# ...                                                 ...
# 3026                 Flower Shops (feat. Morgan Wallen)
# 3027  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 3028                                             Unholy
# 3029                                    One Mississippi
# 3030                           Circles Around This Town
#
#                                                 artists  year  rank  \
# 0                                     [wilson phillips]  1990     1
# 1                                             [roxette]  1990     2
# 2                                     [sinead o connor]  1990     3
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
merged[['sentiment_score','mean_val']] = scaler.fit_transform(
    merged[['sentiment_score','mean_val']])
plt.figure(figsize=(10,6))

sns.lineplot(data=merged, x='year', y='sentiment_score', label='Sentiment')
sns.lineplot(data=merged, x='year', y='mean_val', label='Drug/Alcohol Use Disorders')

plt.legend()
plt.show()

# %%
yearly_lyrics = bb_lyrics.groupby('year')['sentiment_score'].mean().reset_index()
alc_pivot = alc_drug.pivot(
    index='year',
    columns='cause',
    values='mean_val'
).reset_index()
merged_yearly = yearly_lyrics.merge(alc_pivot, on='year')
plt.figure(figsize=(8,6))

sns.regplot(
    data=merged_yearly,
    x='Alcohol use disorders',
    y='sentiment_score',
    color='blue',
    label='Alcohol'
)

plt.legend()
plt.show()

# %%
sns.regplot(
    data=merged_yearly,
    x='Drug use disorders',
    y='sentiment_score',
    color='red',
    label='Drug'
)

plt.legend()
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

scaled = merged2.copy()
robust = RobustScaler()
scale_cols = ['sentiment_score','Alcohol use disorders','Drug use disorders','alc_mentions','drug_mentions']
scaled[scale_cols] = robust.fit_transform(
    scaled[scale_cols])
scaled_group = scaled.groupby('year')[scale_cols].mean().reset_index()
scaled_group.plot(x='year', y=['alc_mentions','Alcohol use disorders'])
plt.show()
scaled_group.plot(x='year', y=['drug_mentions','Drug use disorders'])
plt.show()
scaled_group.plot(x='year', y=['drug_mentions','sentiment_score'])
plt.show()
scaled_group.plot(x='year', y=['alc_mentions','sentiment_score'])
plt.show()
scaled_group.plot(x='year', y=['alc_mentions','Alcohol use disorders','drug_mentions','Drug use disorders'])
# Out:
# <Axes: xlabel='year'>

# %%
#Surprisingly, when songs mention alcohol more, the number of alcohol use disorders go down but when songs mention alcohol less, they go up.
#On the other hand, drug mentions in songs and drug use disorders follow a similar pattern. 
#Sentiment score and alcohol words mentioned goes in oppsite directions. Alcohol words being mentioned in songs tend to have a more negative sentiments. 
#Drug mentions in songs and alcohol use disorders both spiked around 2015 before going down. While drug use disorders continue to ride contrasry to the constantluy shift in alcohol mentioned words
#When drugs are mentioned more, alcohol tends to be mentioned less in songs

# %%
sns.heatmap(scaled_group[scale_cols].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Ethics

# %% [markdown]
# A1 Informed Consent (x): We used publicly available data such as Billboard chart rankings, Spotify popularity metrics, and published song lyrics. Since we did not collect data directly from individuals and no private people can be identified in our dataset, informed consent is not applicable to this project.
#
# A2 Collection Bias (relevant): Our dataset intentionally focuses on mainstream U.S. pop music by sampling the top Billboard-charting songs each year. While this aligns with our research question, chart rankings reflect commercial success and industry promotion rather than the full diversity of musical expression. As a result, our findings describe trends in mainstream popular music consumption and should not be generalized to all genres, independent artists, or global music cultures.
#
# A3 Limit PII Exposure (x): The dataset contains only publicly released song lyrics and chart information. It does not include personal information such as contact details or private user data. As a result, risks related to exposing personal information are minimal.
#
# A4 Downstream Bias Mitigation (relevant): Our project looks at lyrical sentiment during major societal crises and discusses how music may reflect cultural mood or coping. There is a risk that our findings could be misinterpreted as statements about individual mental health or generational traits. To reduce this risk, we present our results as trends in mainstream music rather than direct measures of psychological well-being. We also avoid making claims about specific demographic groups because our dataset does not include information such as race or gender.
#
#
#
# B1 Data Security (relevant): Even though our dataset is publicly available, we take steps to store it responsibly. The data are kept in secure university accounts and repositories. These practices help prevent unauthorized changes, accidental loss, or misuse of analyses related to sensitive societal events.
#
# B2 Right To Be Forgotten (x): Our dataset consists of publicly released lyrics and chart rankings and does not include personal data from private individuals. Because of this, the right to request removal of personal information does not apply to this project.
#
# B3 Data Retention Plan (relevant): While the dataset contains public information and contains minimal privacy risk, we still aim to manage it responsibly. We plan to keep only the cleaned dataset and analysis code needed for reproducibility and delete temporary or duplicate files after the project is complete. This helps minimize unnecessary data storage while maintaining transparency.
#
# C1 Missing Perspectives (relevant): We recognize that our analysis focuses on mainstream U.S. pop music, which may overlook independent, niche, or non-English songs. We have discussed our assumptions with peers and reviewed literature on cultural and societal trends to ensure our interpretations consider broader context and avoid overgeneralizing from our dataset.
#
# C2 Dataset Bias (relevant): Our dataset includes only top songs in the U.S., which reflects commercial popularity rather than the full diversity of music. We acknowledge that certain genres, independent artists, and non-English music are underrepresented, and we limit our conclusions to trends in mainstream pop.
#
# C3 Honest Representation (relevant): Our visualizations and summary statistics accurately reflect the underlying dataset. We avoid overstating trends and clearly indicate when changes are specific to mainstream pop music or linked to specific crises.
#
# C4 Privacy In Analysis (x): Our dataset contains only public song lyrics and chart metadata. No personally identifiable information is included, so privacy risks in the analysis are minimal.
#
# C5 Auditability (relevant): We document all steps of data cleaning, evaluating lyrical sentiments, and other analysis, and store the dataset and code in repositories so that our results can be reproduced and verified if needed. Additionally, we plan to carefully review how Billboard determines the Top 100 each week, including how “listens” are counted across different platforms (streaming, CDs, etc.), to identify any groups that may be underrepresented. While we haven’t yet decided whether to include information about artists’ backgrounds (race, gender, etc.), we recognize that incorporating this could expand the project scope significantly, and we will carefully consider the ethical implications before including such data.
#
#
# D1 Proxy Discrimination (relevant): Our analysis uses publicly available song lyrics and chart data, which do not include sensitive personal attributes. We have reviewed our variables (e.g., Billboard rank, weeks on chart, and lyrical sentiments) to ensure they do not serve as proxies for protected characteristics, and we avoid drawing conclusions about individual artists or demographic groups.
#
# D2 Fairness Across Groups (relevant): Since our project focuses on overall trends in mainstream U.S. pop music, we do not make predictions about individual artists or demographic groups. However, we are aware that certain genres, artist types, and underrepresented groups may not be fully captured in our dataset, and we frame all findings in terms of mainstream pop music trends.
#
# D3 Metric Selection (relevant): We use multiple metrics to evaluate lyrical trends, including sentiment scores (how positive/negative the lyrics are) and measures of lexical diversity (how varied the lyrical vocabulary is). This allows us to capture different aspects of the lyrics and avoid drawing conclusions based on a single metric.
#
# D4 Explainability (relevant): Our analysis methods, including sentiment evaluation and lexical diversity calculations, are transparent and straightforward. We document how each metric is calculated and present results in ways that are interpretable to stakeholders and readers without technical expertise.
#
# D5 Communicate Limitations (relevant): We clearly communicate the limitations of our analysis, including the focus on mainstream U.S. pop music, potential underrepresentation of certain artists or genres, and the fact that sentiment scores are an approximation of lyrical tone rather than a measure of actual listener emotions. These limitations are highlighted in our reports and visualizations.
#
#
#
# E1 Monitoring And Evaluation (x): Our project analyzes historical data and does not involve a live system or predictive model. Therefore, ongoing performance monitoring is not applicable. However, we document all analysis steps carefully so that the process can be reviewed or audited if needed.
#
# E2 Redress (x): Since our work does not interact with users or produce real-time outputs, there is no risk of harm to individuals that would require a redress plan. We acknowledge that misinterpretation of results is possible, and we mitigate this by clearly communicating the scope and limitations of our findings.
#
# E3 Roll back (x): We do not have a deployed model in production, so there is no need for a rollback mechanism. All analysis is conducted offline using static datasets, and results are fully documented and reproducible.
#
# E4 Unintended Use (relevant): While our project does not involve a live deployed model, there is a possibility that others could misinterpret our findings (for example, claiming that negative lyrics indicate individual mental health trends). To prevent misuse, we clearly communicate that our results reflect trends in mainstream U.S. pop music and emphasize the limitations of the dataset and analysis.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Communication: If you are unable to complete your tasks on time, notify the group as soon as possible. iMessages should be responded to within 24 hours, especially when a group member requests assistance.
#
# Meetings: The team will meet synchronously once per week (Tuesdays at 7:30pm) to check progress and plan for the next steps.
#
# Decision-making: The group will aim for consensus; if agreement cannot be reached, decisions will be made by majority vote.
#
# Conflict resolution: The first few minutes of each meeting will be reserved for addressing questions, concerns, or conflicts to ensure open communication and a respectful working environment.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# This is our current timeline
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/10  |  7:30 PM | Conduct background research, share sources  | Formulate 3-paragraph section on background information, compile research |
# | 2/17  |  7:30 PM |  Find and clean datasets | Merge dataset, finalize the data we'll use in the project |
# | 2/24  |  7:30 PM | Start exploratory data analysis and visualizations  | Discuss findings, plan further analysis  |
# | 3/3  |  7:30 PM | Produce final visualizations, begin model selection for analysis | Plan further analysis  |
# | 3/10  |  7:30 PM | Complete analysis, begin writeup of results | Discuss writeups, reach conclusion |
# | 3/16  |  7:30 PM | Fine-tune analyses and writeups| Discuss/edit full project, clean up repo |
# | 3/17  |  7:30 PM | NA | Turn in Final Project & Group Project Surveys |
