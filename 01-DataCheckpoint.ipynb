# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Team List and Credits:
# - Zaria Brand Flu: Background research, Writing - original draft
# - Brooke Kennedy: Conceptualization, Project administration
# - Chris Mo: Data Curation, Experimental investigation,
# - Nhu Duong: Analysis, Methodology, Software, Writing - review & editing
# - Quynh Le: Visualization, Writing, Analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# Has the general sentiment of mainstream U.S. pop music lyrics become more negative and repetitive due to a rise in mental health awareness over the past 25 years (2000–2025)?
#
# More specifically, how did the sentiment of mainstream Spotify and Billboard pop music lyrics change during major societal crises (e.g., the COVID-19 pandemic) compared to the years immediately preceding those crises?
#
# Independent variables: Time (year) and crisis period (pre-COVID vs during COVID).
# Dependent variables: Lyrical sentiment scores and measures of lexical diversity derived from song lyrics.
# Controls variable: include song popularity (Billboard rank, weeks on chart) and consistent sampling across years.
#
# -Comment for TA: We made changes here-

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Over the past five decades, popular music lyrics have undergone systematic shifts in emotional tone, linguistic structure in lyrics, and thematic focus. (1) Lyrical analyses of song lyrics indicate that popular music has become increasingly repetitive and simple, with an emphasis on individual experiences and self expression. These major changes along with an increase in the negative emotional language indicated by words associated with sadness, anger, loneliness, and stress (2). Researchers suggest that these trends in lyrics are a reflection of a broader picture of cultural and psychological shifts within society, such as rising awareness of mental health issues and increased societal stress (3).
#
# The quantitative studies using large lyrical datasets, for our project, the Billboard charting songs and long term collection of popular music demonstrated consistent increases in first person pronouns in songs and more emotional negativity words and phrases. These findings help us strengthen the idea and hypothesis that music lyrics serve as a cultural artifact that mirrors the people, their emotional states and the social priorities of the society as a whole.
#
# Moreover, prior research tells us that these long term trends are not uniform and they tend to shift during different periods of major disruption in society. For example, large-scale crises such the Covid 19 pandemic, the patterns in music  production, lyrical messages and listener preferences changed noticeably. Listeners often lean to music that can provide emotional comfort and relief from stress (4).
#
# We noticed that there are fewer studies that use consistent popularity-based datasets, like the U.S. Billboard Top 100, to directly compare crisis periods to immediately prior years, despite a wealth of evidence of long-term shifts in lyrical emotion. By investigating whether the 9/11 attack and the COVID-19 pandemic reflects a visible shift from the long-term trend of rising negativity in popular U.S. pop music lyrics between 2000 and 2025, this project expands on previous research and continues to look at these patterns to find correlations between societal stress and music.
#
# Reference Links
#
#
# 1. https://www.nature.com/articles/s41598-024-55742-x
# 2. https://www.nature.com/articles/s41598-025-28327-5?fromPaywallRec=false
# 3. https://phys.org/news/2025-12-popular-song-lyrics-negative-analysis.html
# 4. https://www.wuss.org/proceedings/2025/WUSS-2025-Paper-174.pdf
#
# -Comment for TA: We made changes here-

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We, as a group, hypothesize that the period from 2000 to 2025, mainstream U.S. pop music lyrics have become increasingly negative in sentiment and less semantically diverse overall. We further hypothesize that the 9/11 (2021) attack and COVID-19 pandemic (2020–2021) is the reason for this temporarily disrupted this long-term trend, resulting in a relative decrease in negative sentiment or an increase in emotionally comforting lyrical content compared to the years immediately preceding the pandemic.
#
# According to our background research, there is a rise in negative emotional language and reduced lyrical complexity in popular music over history. However, many studies also show that during periods of societal stress and pressure, listeners tend to seek music that provides emotional relief or nostalgia to recall memories. Therefore, we expect the COVID-19 pandemic to produce a measurable deviation from the long-term trend of increasing negativity in the lyrics.
#
# -Comment to TA: We made changes here-

# %% [markdown]
# ## Data
#
#
# Our Ideal Dataset
#
# The ideal dataset we set out to study would include the most popular songs in the United States from 2000 to 2025.
#
# 1. Song title
# 2. Artist
# 3. Year
# 4. Billboard Top 100 rannk
# 5. Number of weeks on the chart
# 6. Song lyrics
# 7. Streaming popularity (if available)
#
# To maintain consistency across years, we propose selecting the top 50 songs per year, resulting in approximately 1,000 total observations. This can be changed throughout the project if we see fit.
#
#
# For the Dataset
# We plan to use a publicly available Kaggle dataset (https://www.kaggle.com/datasets/ludmin/billboard) containing weekly Billboard Top 100 rankings from 1946 onward. This dataset includes song titles, artists, ranks, and chart weeks but does not include lyrics. To address this limitation, we will supplement the Billboard dataset with an external lyrics dataset obtained from a lyrics database or API. These two datasets combined will allow us to perform statistical analysis while getting accurate measures of song popularity and records.
#
#  -Comment for TA: We made changes here-

# %% [markdown]
# ### Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Lyrics for Billboards Top 100 Songs 1946 - 2022
#   - Link to the dataset: https://www.kaggle.com/datasets/rhaamrozenberg/billboards-top-100-song-1946-to-2022-lyrics
#   - Number of observations: 6,879
#   - Number of variables: 5
#   - Variables:
#     - `Song`: Title of song in the billboard hot 100
#     - `Artist names`: List of artists in the song
#     - `Hot100 Ranking Year`: Year in which the song made the year-end hot 100
#     -` Hot100 Rank`: Song's rank within the year-end hot 100 list
#     - `Lyrics`: Preprocessed lyrics represented as a list of words split by whitespace, each element case standardized
#
# - Dataset #2
#   - Dataset Name: Global Trends in Mental Health Disorder
#   - Link to dataset: https://www.kaggle.com/datasets/thedevastator/uncover-global-trends-in-mental-health-disorder
#   - Number of observations: 108,553
#   - Number of Variables: 11
#   - Variables:
#     - `Index`: Index of DataFrame
#     - `Entity`: Unique identifier for each country or region included in the data set.
#     - `Code`: Unique code associated with an Entity/Country or region included in the data set.
#     - `Year`: Year that the data about that particular Entity/Country was collected.
#     - `Schizophrenia (%)`: Percentage of people with schizophrenia in that country/region during that year.
#     - `Bipolar Disorder (%)`: Percentage of people with bipolar disorder in that country/region during that year.
#     - `Eating Disorder (%)`: Percentage of people with eating disorders in that country/region during that year.
#     - `Anxiety Disorder (%)`: Percentage of people with anxiety disorders in that country/region during that year.
#     - `Drug Use Disorder (%)`: Percentage of people with drug use disorders in that country/region during that year.
#     - `Depression (%)`: Percentage of people with depression in that country/region during that year.
#     - `Alcohol Use Disorder (%)`: Percentage of people with alcohol use disorders in that country/region during that year.
#   - Shortcomings:
#     - Messy and redundant entries
#     - Only gives complete data from 1990-2017
#
# We plan to combine the datasets by first extracting the clean portion of the U.S. mental health dataset and merging the statistics by year.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1har3-M6UhsLSLkfvsXH_x2rdyxfH_w7w', 'filename':'lyric_dataset.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1FY19P0ApbPEPFObWy9pRza1Op7FLph_m', 'filename':'mental_health_dataset.csv'},

]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading lyric_dataset.csv:   0%|          | 0.00/16.1M [00:00<?, ?B/s]
# Downloading lyric_dataset.csv:   2%|▏         | 323k/16.1M [00:00<00:04, 3.22MB/s]
# Downloading lyric_dataset.csv:  11%|█▏        | 1.85M/16.1M [00:00<00:01, 10.3MB/s]
# Downloading lyric_dataset.csv:  35%|███▍      | 5.60M/16.1M [00:00<00:00, 22.7MB/s]
# Downloading lyric_dataset.csv:  55%|█████▌    | 8.87M/16.1M [00:00<00:00, 26.6MB/s]
# Downloading lyric_dataset.csv:  78%|███████▊  | 12.6M/16.1M [00:00<00:00, 30.2MB/s]
# Overall Download Progress:  50%|█████     | 1/2 [00:02<00:02,  2.57s/it]
# Successfully downloaded: lyric_dataset.csv
# Downloading mental_health_dataset.csv:   0%|          | 0.00/4.88M [00:00<?, ?B/s]
# Downloading mental_health_dataset.csv:   7%|▋         | 339k/4.88M [00:00<00:01, 3.33MB/s]
# Downloading mental_health_dataset.csv:  40%|███▉      | 1.94M/4.88M [00:00<00:00, 10.7MB/s]
# Overall Download Progress: 100%|██████████| 2/2 [00:04<00:00,  2.27s/it]
# Successfully downloaded: mental_health_dataset.csv

# %% [markdown]
# ### A collection of lyrics from Billboard Top 100 songs ranging from 1946 to 2022
#     This dataset contains five metrics: song name, lyrics, artist name, ranking year, and rank. Song name is the name of the song. Lyrics are the words of the song. The artist's name is the name of the artist who created the song being ranked. Ranking year is the year in which the song is being ranked. And rank is the song's placement in the top 100 during a given year. There are a few shortcomings with this dataset. The first shortcoming is that it only goes up to the year 2022, so we will either need to find a secondary dataset or lower the range we will be observing to match this dataset. Secondly, there are some null values in the lyrics column that we will have to filter out.

# %%
## Reading in the dataset
import pandas as pd
import ast
lyric_df = pd.read_csv('./data/00-raw/lyric_dataset.csv')
## Rename columns for simplicity
lyric_df.columns = ['song','artists','year','rank','lyrics']
lyric_df['artists'] = lyric_df['artists'].apply(ast.literal_eval)
lyric_df
# Out:
#                                                    song  \
# 0                  Prisoner of Love - Remastered - 1992
# 1                                       To Each His Own
# 2                                             The Gypsy
# 3                                     Five Minutes More
# 4                                     Rumors Are Flying
# ...                                                 ...
# 6874                 Flower Shops (feat. Morgan Wallen)
# 6875  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 6876                                             Unholy
# 6877                                    One Mississippi
# 6878                           Circles Around This Town
#
#                                                 artists  year  rank  \
# 0                                          [perry como]  1946     1
# 1                                         [eddy howard]  1946     2
# 2                                       [the ink spots]  1946     3
# 3                                       [frank sinatra]  1946     4
# 4                                       [frankie carle]  1946     5
# ...                                                 ...   ...   ...
# 6874                            [ernest, morgan wallen]  2022    96
# 6875  [jnr choi, m24, g herbo, fivio foreign, russ m...  2022    97
# 6876                            [sam smith, kim petras]  2022    98
# 6877                                       [kane brown]  2022    99
# 6878                                     [maren morris]  2022   100
#
#                                                  lyrics
# 0     ['someone', 'that', 'i', 'belong', 'to', 'does...
# 1     ['a', 'rose', 'must', 'remain', 'with', 'the',...
# 2     ['in', 'a', 'quaint', 'caravan', 'theres', 'a'...
# 3     ['dear', 'this', 'evening', 'seemed', 'to', 'g...
# 4     ['rumors', 'are', 'flying', 'that', 'youve', '...
# ...                                                 ...
# 6874  ['its', 'a', 'beautiful', 'day', 'shes', 'been...
# 6875  ['sit', 'by', 'myself', 'talking', 'to', 'the'...
# 6876  ['mummy', 'dont', 'know', 'daddys', 'getting',...
# 6877  ['you', 'and', 'i', 'had', 'this', 'off', 'and...
# 6878  ['i', 'swear', 'i', 'dont', 'know', 'how', 'i'...
#
# [6879 rows x 5 columns]

# %%
print(f'There are {lyric_df.shape[0]} rows in the dataframe, with {lyric_df.shape[1]} columns.')
# Out:
# There are 6879 rows in the dataframe, with 5 columns.

# %% [markdown]
# Examining null values, if any exist in the dataset

# %%
print(lyric_df.isna().any())
# Out:
# song       False
# artists    False
# year       False
# rank       False
# lyrics      True
# dtype: bool

# %% [markdown]
# As shown, there are null values in the Lyric column

# %%
null_lyrics = lyric_df[lyric_df['lyrics'].isna()]
display(null_lyrics)
# Out:
#                                                    song  \
# 5                              Oh! What It Seemed to Be
# 13                                      To Each His Own
# 14                                   Ole Buttermilk Sky
# 17                                  The Old Lamplighter
# 20    Jocelyn, Op. 100: Berceuse (Arr. For vocal, vi...
# ...                                                 ...
# 6706  Dakiti (Originally Performed by Bad Bunny & Jh...
# 6725                                      Wants & Needs
# 6798                                 Yo Me Porto Bonito
# 6811                           Jimmy Cooks - Lofi Cover
# 6867                            A Holly Jolly Christmas
#
#                                                 artists  year  rank lyrics
# 5                   [frankie carle his piano orchestra]  1946     6    NaN
# 13                        [freddy martin his orchestra]  1946    14    NaN
# 14                            [kay kyser his orchestra]  1946    15    NaN
# 17                           [sammy kaye his orchestra]  1946    18    NaN
# 20    [benjamin godard, bing crosby, jascha heifetz,...  1946    20    NaN
# ...                                                 ...   ...   ...    ...
# 6706                                 [backing business]  2021    28    NaN
# 6725                                    [homixide gang]  2021    47    NaN
# 6798                                         [bad bunn]  2022    20    NaN
# 6811                    [covers unplugged, wild issues]  2022    33    NaN
# 6867                                        [burl ives]  2022    89    NaN
#
# [847 rows x 5 columns]

# %% [markdown]
# There are about 847 songs in our dataset without lyrics, but we plan to drop those. Many have "orchestra" in the author names and some are Lofi covers, which by nature do not have lyrics as well and may be based on other artists. One mentions Bad Bunny as an artist, and we may not be able to do meaningful language analysis on different languages at the moment.
#
# Thus, we decided to drop the values to make the data easier to work with. Since null values are only present in the lyric column, we can use `pd.dropna(how='any')` to drop the correct rows.

# %%
lyrics_clean = lyric_df.dropna(how='any')
lyrics_clean['lyrics'] = lyrics_clean['lyrics'].apply(ast.literal_eval)
lyrics_clean
# Out:
# /tmp/ipykernel_534/1171233541.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lyrics_clean['lyrics'] = lyrics_clean['lyrics'].apply(ast.literal_eval)
#                                                    song  \
# 0                  Prisoner of Love - Remastered - 1992
# 1                                       To Each His Own
# 2                                             The Gypsy
# 3                                     Five Minutes More
# 4                                     Rumors Are Flying
# ...                                                 ...
# 6874                 Flower Shops (feat. Morgan Wallen)
# 6875  TO THE MOON (feat. Fivio Foreign, Russ Million...
# 6876                                             Unholy
# 6877                                    One Mississippi
# 6878                           Circles Around This Town
#
#                                                 artists  year  rank  \
# 0                                          [perry como]  1946     1
# 1                                         [eddy howard]  1946     2
# 2                                       [the ink spots]  1946     3
# 3                                       [frank sinatra]  1946     4
# 4                                       [frankie carle]  1946     5
# ...                                                 ...   ...   ...
# 6874                            [ernest, morgan wallen]  2022    96
# 6875  [jnr choi, m24, g herbo, fivio foreign, russ m...  2022    97
# 6876                            [sam smith, kim petras]  2022    98
# 6877                                       [kane brown]  2022    99
# 6878                                     [maren morris]  2022   100
#
#                                                  lyrics
# 0     [someone, that, i, belong, to, doesnt, belong,...
# 1     [a, rose, must, remain, with, the, sun, and, t...
# 2     [in, a, quaint, caravan, theres, a, lady, they...
# 3     [dear, this, evening, seemed, to, go, so, awfu...
# 4     [rumors, are, flying, that, youve, got, me, si...
# ...                                                 ...
# 6874  [its, a, beautiful, day, shes, been, crying, a...
# 6875  [sit, by, myself, talking, to, the, moon, teh,...
# 6876  [mummy, dont, know, daddys, getting, hot, at, ...
# 6877  [you, and, i, had, this, off, and, on, so, lon...
# 6878  [i, swear, i, dont, know, how, i, trusted, a, ...
#
# [6032 rows x 5 columns]

# %%
## visualizing the distribution of years and rank in the clean dataset
import matplotlib.pyplot as plt

lyrics_clean['year'].hist()
plt.show()
lyrics_clean['rank'].hist()
# Out:
# <Axes: >

# %% [markdown]
# As shown, the 1940s-1950s had many more null lyric values than the rest of the dataset, likely because the songs are harder to find definitive lyrics for almost 80 years later. Since our secondary dataset only has data from 1990-2017, we will not have to worry about this particular problem. The rank also doesn't seem to affect the missingness, so our clean data is ready for analysis.

# %%
## gather data from those available in the mental health dataset: 1990-2017

filtered_years = lyrics_clean[(lyrics_clean['year'] >= 1990)&(lyrics_clean['year'] <= 2017)]
filtered_years
# Out:
#                                                    song  \
# 3585                                            Hold On
# 3586  It Must Have Been Love - From the Film "Pretty...
# 3587                               Nothing Compares 2 U
# 3588                                             Poison
# 3589                                              Vogue
# ...                                                 ...
# 6374                          Havana (feat. Young Thug)
# 6375                         What Lovers Do (feat. SZA)
# 6376                                           do re mi
# 6377                                        Look At Me!
# 6378                                        The Fighter
#
#                               artists  year  rank  \
# 3585                [wilson phillips]  1990     1
# 3586                        [roxette]  1990     2
# 3587                [sinead o connor]  1990     3
# 3588                 [bell biv devoe]  1990     4
# 3589                        [madonna]  1990     5
# ...                               ...   ...   ...
# 6374     [camila cabello, young thug]  2017    96
# 6375                  [maroon 5, sza]  2017    97
# 6376                      [blackbear]  2017    98
# 6377                   [xxxtentacion]  2017    99
# 6378  [keith urban, carrie underwood]  2017   100
#
#                                                  lyrics
# 3585  [i, know, theres, pain, why, do, lock, yoursel...
# 3586  [it, must, have, been, love, but, its, over, n...
# 3587  [its, been, seven, hours, and, fifteen, days, ...
# 3588  [yeah, spyderman, and, freeze, in, full, effec...
# 3589  [strike, a, pose, strike, a, pose, vogue, vogu...
# ...                                                 ...
# 6374  [hey, havana, ooh, nana, ayy, half, of, my, he...
# 6375  [say, say, say, hey, hey, now, baby, oh, mama,...
# 6376  [do, re, mi, fa, so, yeah, yeah, yeah, oh, do,...
# 6377  [yah, ayy, yah, ayy, yah, yah, yah, ayy, ayy, ...
# 6378  [i, know, he, hurt, you, made, you, scared, of...
#
# [2551 rows x 5 columns]

# %% [markdown]
# Adding some features that might be useful for EDA in the next checkpoint

# %%
filtered_years['num_artists'] = filtered_years['artists'].apply(len)
filtered_years['num_unique_words'] = filtered_years['lyrics'].apply(lambda x: len(set(x)))
filtered_years
# Out:
# /tmp/ipykernel_534/831033759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_years['num_artists'] = filtered_years['artists'].apply(len)
# /tmp/ipykernel_534/831033759.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_years['num_unique_words'] = filtered_years['lyrics'].apply(lambda x: len(set(x)))
#                                                    song  \
# 3585                                            Hold On
# 3586  It Must Have Been Love - From the Film "Pretty...
# 3587                               Nothing Compares 2 U
# 3588                                             Poison
# 3589                                              Vogue
# ...                                                 ...
# 6374                          Havana (feat. Young Thug)
# 6375                         What Lovers Do (feat. SZA)
# 6376                                           do re mi
# 6377                                        Look At Me!
# 6378                                        The Fighter
#
#                               artists  year  rank  \
# 3585                [wilson phillips]  1990     1
# 3586                        [roxette]  1990     2
# 3587                [sinead o connor]  1990     3
# 3588                 [bell biv devoe]  1990     4
# 3589                        [madonna]  1990     5
# ...                               ...   ...   ...
# 6374     [camila cabello, young thug]  2017    96
# 6375                  [maroon 5, sza]  2017    97
# 6376                      [blackbear]  2017    98
# 6377                   [xxxtentacion]  2017    99
# 6378  [keith urban, carrie underwood]  2017   100
#
#                                                  lyrics  num_artists  \
# 3585  [i, know, theres, pain, why, do, lock, yoursel...            1
# 3586  [it, must, have, been, love, but, its, over, n...            1
# 3587  [its, been, seven, hours, and, fifteen, days, ...            1
# 3588  [yeah, spyderman, and, freeze, in, full, effec...            1
# 3589  [strike, a, pose, strike, a, pose, vogue, vogu...            1
# ...                                                 ...          ...
# 6374  [hey, havana, ooh, nana, ayy, half, of, my, he...            2
# 6375  [say, say, say, hey, hey, now, baby, oh, mama,...            2
# 6376  [do, re, mi, fa, so, yeah, yeah, yeah, oh, do,...            1
# 6377  [yah, ayy, yah, ayy, yah, yah, yah, ayy, ayy, ...            1
# 6378  [i, know, he, hurt, you, made, you, scared, of...            2
#
#       num_unique_words
# 3585               107
# 3586                80
# 3587               106
# 3588               208
# 3589               158
# ...                ...
# 6374               128
# 6375                77
# 6376               121
# 6377               100
# 6378                87
#
# [2551 rows x 7 columns]

# %% [markdown]
# ### Dataset #2 : Global Trend in Mental Health Disorders
#
# See instructions above for Dataset #1.  Feel free to keep adding as many more datasets as you need.  Put each new dataset in its own section just like these.
#
# Lastly if you do have multiple datasets, add another section where you demonstrate how you will join, align, cross-reference or whatever to combine data from the different datasets
#
# Please note that you can always keep adding more datasets in the future if these datasets you turn in for the checkpoint aren't sufficient.  The goal here is demonstrate that you can obtain and wrangle data.  You are not tied down to only use what you turn in right now.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA
mental_health_df = pd.read_csv('data/00-raw/mental_health_dataset.csv')
mental_health_df
# Out:
# /var/folders/rj/7l0ph7313tb4vb0vgzj7qkpr0000gn/T/ipykernel_37735/2593458922.py:2: DtypeWarning: Columns (0: Bipolar disorder (%), 1: Eating disorders (%)) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental_health_df = pd.read_csv('data/00-raw/mental_health_dataset.csv')
#          index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0            0  Afghanistan  AFG  1990           0.16056             0.697779
# 1            1  Afghanistan  AFG  1991          0.160312             0.697961
# 2            2  Afghanistan  AFG  1992          0.160135             0.698107
# 3            3  Afghanistan  AFG  1993          0.160037             0.698257
# 4            4  Afghanistan  AFG  1994          0.160022             0.698469
# ...        ...          ...  ...   ...               ...                  ...
# 108548  108548     Zimbabwe  ZWE  2013      303564.60359                  NaN
# 108549  108549     Zimbabwe  ZWE  2014     311665.769283                  NaN
# 108550  108550     Zimbabwe  ZWE  2015     320638.507158                  NaN
# 108551  108551     Zimbabwe  ZWE  2016     330437.353798                  NaN
# 108552  108552     Zimbabwe  ZWE  2017     340583.157405                  NaN
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0                  0.101855               4.828830                1.677082
# 1                  0.099313               4.829740                1.684746
# 2                  0.096692               4.831108                1.694334
# 3                  0.094336               4.830864                1.705320
# 4                  0.092439               4.829423                1.716069
# ...                     ...                    ...                     ...
# 108548                  NaN                    NaN                     NaN
# 108549                  NaN                    NaN                     NaN
# 108550                  NaN                    NaN                     NaN
# 108551                  NaN                    NaN                     NaN
# 108552                  NaN                    NaN                     NaN
#
#         Depression (%)  Alcohol use disorders (%)
# 0             4.071831                   0.672404
# 1             4.079531                   0.671768
# 2             4.088358                   0.670644
# 3             4.096190                   0.669738
# 4             4.099582                   0.669260
# ...                ...                        ...
# 108548             NaN                        NaN
# 108549             NaN                        NaN
# 108550             NaN                        NaN
# 108551             NaN                        NaN
# 108552             NaN                        NaN
#
# [108553 rows x 11 columns]

# %% [markdown]
# This dataset shows the annual prevalence of several psychological and substance use disorders in about 276 different countries across the globe from the period of 1990 to 2017. Each row of the dataset shows one country and the equivalent year of the country. The key metrics are the percentages indicating the proportion of the population that can be associated with a given disorder. The disorders found in this dataset consists of schizophrenia, bipolar disorder, eating disorders, anxiety disorders, drug use disorders, depression, and disorders due to alcohol use. Because the values are expressed as percentage, out of the total population of that region, a certain value such as 4.8% for anxiety disorders means that approximately 5 out of every 100 people were estimated to be diagnosed with an anxiety disorder during that specific year.

# %% [markdown]
# Extract only the United States' data, since the Billboard Hot100 is only applicable in one country

# %%
usa_only = mental_health_df[(mental_health_df['Entity'] == 'United States')|(mental_health_df['Code']=='USA')]
usa_only
# Out:
#          index         Entity Code  Year Schizophrenia (%)  \
# 6076      6076  United States  USA  1990          0.340897
# 6077      6077  United States  USA  1991          0.338913
# 6078      6078  United States  USA  1992          0.337343
# 6079      6079  United States  USA  1993          0.336207
# 6080      6080  United States  USA  1994          0.335536
# ...        ...            ...  ...   ...               ...
# 108184  108184  United States  USA  2013   14854640.943900
# 108185  108185  United States  USA  2014   15000147.279000
# 108186  108186  United States  USA  2015   15155130.939300
# 108187  108187  United States  USA  2016   15321682.155200
# 108188  108188  United States  USA  2017   15499359.535800
#
#        Bipolar disorder (%) Eating disorders (%)  Anxiety disorders (%)  \
# 6076               0.653706             0.468676               6.576884
# 6077               0.653953             0.473575               6.553351
# 6078               0.654205              0.47861               6.536143
# 6079               0.654431             0.483539               6.525536
# 6080                0.65462             0.488235               6.522278
# ...                     ...                  ...                    ...
# 108184                  NaN                  NaN                    NaN
# 108185                  NaN                  NaN                    NaN
# 108186                  NaN                  NaN                    NaN
# 108187                  NaN                  NaN                    NaN
# 108188                  NaN                  NaN                    NaN
#
#         Drug use disorders (%)  Depression (%)  Alcohol use disorders (%)
# 6076                  2.367794        4.677591                   2.173751
# 6077                  2.345466        4.660871                   2.139292
# 6078                  2.339515        4.651949                   2.107931
# 6079                  2.347095        4.648701                   2.080669
# 6080                  2.365738        4.649294                   2.058632
# ...                        ...             ...                        ...
# 108184                     NaN             NaN                        NaN
# 108185                     NaN             NaN                        NaN
# 108186                     NaN             NaN                        NaN
# 108187                     NaN             NaN                        NaN
# 108188                     NaN             NaN                        NaN
#
# [496 rows x 11 columns]

# %% [markdown]
# After exploring the data in Excel, we saw that there are complete rows of data for the first 27 rows, and each subsequent row has missing and/or dirty data. We will only be using the first few rows for that reason.

# %%
usa_only = usa_only.dropna(how='any')
usa_only
# Out:
#       index         Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 6093    4.786623     2.045624
# 6094    4.776402     2.023935
# 6095    4.765950     2.005749
# 6096    4.761551     1.998437
# 6097    4.762322     1.999569
# 6098    4.765481     2.001951
# 6099    4.772422     2.005814
# 6100    4.782222     2.011345
# 6101    4.795954     2.018738
# 6102    4.813114     2.028263
# 6103    4.835610     2.040087

# %% [markdown]
# This dataset specifically shows the commonality of several mental and substance use disorders that have been in the United States from 1990 to 2017. Similar to the dataset above, the values in this dataset are also expressed as percentage of the total population in America. With a value such as 6.7% for anxiety disorders means that approximately 7 out of every 100 people were estimated to have an anxiety disorder during that year.
#
# There are several important metrics that stand out in this dataset. Anxiety disorders are consistently the most common condition, staying between about 6.5% and 7.0% of the population, indicating a  persistent mental health burden of society. Following that, depression is the next most common condition; it affects roughly 4.6–4.8% of the population across the period, meaning about 5 in 100 people or 1 in 20 individuals experience depressive disorders in a given year. Although these percentages may seem small, they represent millions of individuals when applied to the U.S. population. In contrast to those growths, schizophrenia and bipolar disorder affect less than 1% of people (approximately 0.65% and 0.33-0.34% respectively), but they are often severe and lifelong conditions that require ongoing care and further support.
#
# One of the most surprising patterns in the dataset is the rise in drug use disorders, which increased from about 2.4% in 1990 to more than 3.4% by 2017. That change represents millions of additional people struggling with substance use, and it reflects a  broader national concerns such as the opioid crisis. Meanwhile, alcohol use disorders declined slightly in the 1990s (~2.2-2.0% from 1990-1999) and then stabilized (~2.03-2.04% from 2000-2017), suggesting that patterns of substance use may be shifting rather than simply increasing overall. Although eating disorders remain below 0.55% and show a small rise through the early 2000s (~0.46-0.51% from 1990-2000) before starting to stabilize (~0.5 from 2001-2017), this mental problem should still be considered serious due to their high health risks for the society.
#
# To analyze these percentages, it is helpful to consider scale as well. For example, with a U.S. population of roughly 325 million in 2017, a 6.6% prevalence of anxiety disorders corresponds to over 21 million people. For these dataset,  small percentage changes can represent millions of individuals in the country. Unlike clinical measurements like blood glucose levels, these metrics do not have a safe or dangerous range where we can estimate; they can only represent approximation of how common each disorder is in the population. However, steady increases, as shown in substance use disorders, can be a warning sign that public health crises are growing and that new medical programs might be needed to minimize them.
#
# There are several important limitations and potential sources of bias in this dataset. In particular, these numbers are only approximation based on surveys, medical records, and statistical models, not exact counts. Many people never receive a formal diagnosis due to stigma, lack of access to healthcare, or cultural barriers, which means the true number has the potential to be higher or lower. Changes in diagnostic criteria and increased awareness over time can also make it look like some disorders are becoming more common when, in fact, they are simply being recognized more widely. In addition, because the data is aggregated at the national level, it hides important differences between regions (such as different states), age groups, and communities that experience mental health challenges in very different ways.
#
# Overall, this dataset provides a valuable view of mental health trends in the United States. This dataset can highlights the high and persistent prevalence of anxiety and depression, the relative stability of severe psychiatric disorders like schizophrenia and bipolar disorder, and the concerning rise in drug use disorders. Most importantly, the dataset should be interpreted cautiously due to potential diagnostic, reporting, and aggregation biases.

# %%
usa_only.dtypes
# Out:
# year                   str
# schizophrenia          str
# bipolar             object
# eating_disorder     object
# anxiety            float64
# drug_use           float64
# depression         float64
# alcohol_use        float64
# dtype: object

# %% [markdown]
# Fixing the data types

# %%
fix_cols = ['schizophrenia','bipolar','eating_disorder']
usa_only['year'] = usa_only['year'].astype(int)
for col in fix_cols:
    usa_only[col] = usa_only[col].astype(float)
usa_only.dtypes
# Out:
# year                 int64
# schizophrenia      float64
# bipolar            float64
# eating_disorder    float64
# anxiety            float64
# drug_use           float64
# depression         float64
# alcohol_use        float64
# dtype: object

# %%
usa_only.to_csv('data/02-processed/usa_mental_health.csv')

# %% [markdown]
# ## Ethics

# %% [markdown]
# A1 Informed Consent (x): We used publicly available data such as Billboard chart rankings, Spotify popularity metrics, and published song lyrics. Since we did not collect data directly from individuals and no private people can be identified in our dataset, informed consent is not applicable to this project.
#
# A2 Collection Bias (relevant): Our dataset intentionally focuses on mainstream U.S. pop music by sampling the top Billboard-charting songs each year. While this aligns with our research question, chart rankings reflect commercial success and industry promotion rather than the full diversity of musical expression. As a result, our findings describe trends in mainstream popular music consumption and should not be generalized to all genres, independent artists, or global music cultures.
#
# A3 Limit PII Exposure (x): The dataset contains only publicly released song lyrics and chart information. It does not include personal information such as contact details or private user data. As a result, risks related to exposing personal information are minimal.
#
# A4 Downstream Bias Mitigation (relevant): Our project looks at lyrical sentiment during major societal crises and discusses how music may reflect cultural mood or coping. There is a risk that our findings could be misinterpreted as statements about individual mental health or generational traits. To reduce this risk, we present our results as trends in mainstream music rather than direct measures of psychological well-being. We also avoid making claims about specific demographic groups because our dataset does not include information such as race or gender.
#
#
#
# B1 Data Security (relevant): Even though our dataset is publicly available, we take steps to store it responsibly. The data are kept in secure university accounts and repositories. These practices help prevent unauthorized changes, accidental loss, or misuse of analyses related to sensitive societal events.
#
# B2 Right To Be Forgotten (x): Our dataset consists of publicly released lyrics and chart rankings and does not include personal data from private individuals. Because of this, the right to request removal of personal information does not apply to this project.
#
# B3 Data Retention Plan (relevant): While the dataset contains public information and contains minimal privacy risk, we still aim to manage it responsibly. We plan to keep only the cleaned dataset and analysis code needed for reproducibility and delete temporary or duplicate files after the project is complete. This helps minimize unnecessary data storage while maintaining transparency.
#
# C1 Missing Perspectives (relevant): We recognize that our analysis focuses on mainstream U.S. pop music, which may overlook independent, niche, or non-English songs. We have discussed our assumptions with peers and reviewed literature on cultural and societal trends to ensure our interpretations consider broader context and avoid overgeneralizing from our dataset.
#
# C2 Dataset Bias (relevant): Our dataset includes only top songs in the U.S., which reflects commercial popularity rather than the full diversity of music. We acknowledge that certain genres, independent artists, and non-English music are underrepresented, and we limit our conclusions to trends in mainstream pop.
#
# C3 Honest Representation (relevant): Our visualizations and summary statistics accurately reflect the underlying dataset. We avoid overstating trends and clearly indicate when changes are specific to mainstream pop music or linked to specific crises.
#
# C4 Privacy In Analysis (x): Our dataset contains only public song lyrics and chart metadata. No personally identifiable information is included, so privacy risks in the analysis are minimal.
#
# C5 Auditability (relevant): We document all steps of data cleaning, evaluating lyrical sentiments, and other analysis, and store the dataset and code in repositories so that our results can be reproduced and verified if needed. Additionally, we plan to carefully review how Billboard determines the Top 100 each week, including how “listens” are counted across different platforms (streaming, CDs, etc.), to identify any groups that may be underrepresented. While we haven’t yet decided whether to include information about artists’ backgrounds (race, gender, etc.), we recognize that incorporating this could expand the project scope significantly, and we will carefully consider the ethical implications before including such data.
#
#
# D1 Proxy Discrimination (relevant): Our analysis uses publicly available song lyrics and chart data, which do not include sensitive personal attributes. We have reviewed our variables (e.g., Billboard rank, weeks on chart, and lyrical sentiments) to ensure they do not serve as proxies for protected characteristics, and we avoid drawing conclusions about individual artists or demographic groups.
#
# D2 Fairness Across Groups (relevant): Since our project focuses on overall trends in mainstream U.S. pop music, we do not make predictions about individual artists or demographic groups. However, we are aware that certain genres, artist types, and underrepresented groups may not be fully captured in our dataset, and we frame all findings in terms of mainstream pop music trends.
#
# D3 Metric Selection (relevant): We use multiple metrics to evaluate lyrical trends, including sentiment scores (how positive/negative the lyrics are) and measures of lexical diversity (how varied the lyrical vocabulary is). This allows us to capture different aspects of the lyrics and avoid drawing conclusions based on a single metric.
#
# D4 Explainability (relevant): Our analysis methods, including sentiment evaluation and lexical diversity calculations, are transparent and straightforward. We document how each metric is calculated and present results in ways that are interpretable to stakeholders and readers without technical expertise.
#
# D5 Communicate Limitations (relevant): We clearly communicate the limitations of our analysis, including the focus on mainstream U.S. pop music, potential underrepresentation of certain artists or genres, and the fact that sentiment scores are an approximation of lyrical tone rather than a measure of actual listener emotions. These limitations are highlighted in our reports and visualizations.
#
#
#
# E1 Monitoring And Evaluation (x): Our project analyzes historical data and does not involve a live system or predictive model. Therefore, ongoing performance monitoring is not applicable. However, we document all analysis steps carefully so that the process can be reviewed or audited if needed.
#
# E2 Redress (x): Since our work does not interact with users or produce real-time outputs, there is no risk of harm to individuals that would require a redress plan. We acknowledge that misinterpretation of results is possible, and we mitigate this by clearly communicating the scope and limitations of our findings.
#
# E3 Roll back (x): We do not have a deployed model in production, so there is no need for a rollback mechanism. All analysis is conducted offline using static datasets, and results are fully documented and reproducible.
#
# E4 Unintended Use (relevant): While our project does not involve a live deployed model, there is a possibility that others could misinterpret our findings (for example, claiming that negative lyrics indicate individual mental health trends). To prevent misuse, we clearly communicate that our results reflect trends in mainstream U.S. pop music and emphasize the limitations of the dataset and analysis.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Communication: If you are unable to complete your tasks on time, notify the group as soon as possible. iMessages should be responded to within 24 hours, especially when a group member requests assistance.
#
# Meetings: The team will meet synchronously once per week (Tuesdays at 7:30pm) to check progress and plan for the next steps.
#
# Decision-making: The group will aim for consensus; if agreement cannot be reached, decisions will be made by majority vote.
#
# Conflict resolution: The first few minutes of each meeting will be reserved for addressing questions, concerns, or conflicts to ensure open communication and a respectful working environment.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# This is our current timeline
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/10  |  7:30 PM | Conduct background research, share sources  | Formulate 3-paragraph section on background information, compile research |
# | 2/17  |  7:30 PM |  Find and clean datasets | Merge dataset, finalize the data we'll use in the project |
# | 2/24  |  7:30 PM | Start exploratory data analysis and visualizations  | Discuss findings, plan further analysis  |
# | 3/3  |  7:30 PM | Produce final visualizations, begin model selection for analysis | Plan further analysis  |
# | 3/10  |  7:30 PM | Complete analysis, begin writeup of results | Discuss writeups, reach conclusion |
# | 3/16  |  7:30 PM | Fine-tune analyses and writeups| Discuss/edit full project, clean up repo |
# | 3/17  |  7:30 PM | NA | Turn in Final Project & Group Project Surveys |
